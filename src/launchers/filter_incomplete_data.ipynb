# %%
import pandas as pd
import numpy as np

# %%
with open("../results.csv", "r") as f:
    df = pd.read_csv(f, sep="\s+", dtype='str', keep_default_na=False)
df
# Out:
#                    hash        date      time   elapsed rng offset  \
# 0      2328d7d51b69aa46  2025.10.08  08:08:03  1.11e-03   1      0
# 1      0bf5c7b73b605c41  2025.10.08  08:08:03  2.54e-04   1      0
# 2      06c5f05cc73e5e3a  2025.10.08  08:08:03  3.48e-04   1      0
# 3      1de1446a8bca2727  2025.10.08  08:08:03  2.80e-04   1      0
# 4      4b5b77d57216a95a  2025.10.08  08:08:03  3.49e-04   1      0
# ...                 ...         ...       ...       ...  ..    ...
# 45642  5b0a9d95e9f6b568  2025.10.24  23:02:16  5.16e+03   1      0
# 45643  6c0483155e0f61ef  2025.10.24  23:03:18  1.36e+04   1      0
# 45644  13d6cb948de589c3  2025.10.25  03:12:04  1.99e-03   1      0
# 45645  13d6cb948de589c3  2025.10.25  03:12:53  9.38e-03   1      0
# 45646  13d6cb948de589c3  2025.10.25  03:14:19  7.08e+01   1      0
#
#       bitsPerSample srcLittleEndian dstLittleEndian dim     m stride  \
# 0                 8               0               0   1     2      1
# 1                 8               0               0   1     2      2
# 2                 8               0               0   1     2      3
# 3                 8               0               0   1     2      4
# 4                 8               0               0   1     2      5
# ...             ...             ...             ...  ..   ...    ...
# 45642            16               1               1   5    10      8
# 45643            16               1               0   7    10      9
# 45644            16               0               0   1  4096      0
# 45645            16               0               0   1  4096      0
# 45646            16               0               0   1  4096      0
#
#                  N    Mtotal curtask Ntasks          sum              sum2  \
# 0               20         2       0      1           20               202
# 1               20         2       0      1           20               202
# 2               20         2       0      1           20               202
# 3               20         2       0      1           20               202
# 4               20         2       0      1           20               232
# ...            ...       ...     ...    ...          ...               ...
# 45642  10000000000    100000       0      1  10000000000  1000010012285638
# 45643  10000000000  10000000       0      1  10000000000    10010002991746
# 45644        40960      4096       0      1        40960        1677721600
# 45645        40960      4096       0      1        40960        1677721600
# 45646        40960      4096       0      1        40960        1677721600
#
#                      chi2cdf parameters_ok
# 0      3.452791539814230e-01             1
# 1      3.452791539814230e-01             1
# 2      3.452791539814230e-01             1
# 3      3.452791539814230e-01             1
# 4      9.263617298796973e-01             1
# ...                      ...           ...
# 45642  3.684624952247000e-01             1
# 45643  7.225993333332424e-01             1
# 45644  1.000000000000000e+00             1
# 45645  1.000000000000000e+00             1
# 45646  1.000000000000000e+00             1
#
# [45647 rows x 20 columns]

# %%
mask = (df.stride != '0')

# %%
df_filtered = df[mask]
df_filtered
# Out:
#                    hash        date      time   elapsed rng offset  \
# 0      2328d7d51b69aa46  2025.10.08  08:08:03  1.11e-03   1      0
# 1      0bf5c7b73b605c41  2025.10.08  08:08:03  2.54e-04   1      0
# 2      06c5f05cc73e5e3a  2025.10.08  08:08:03  3.48e-04   1      0
# 3      1de1446a8bca2727  2025.10.08  08:08:03  2.80e-04   1      0
# 4      4b5b77d57216a95a  2025.10.08  08:08:03  3.49e-04   1      0
# ...                 ...         ...       ...       ...  ..    ...
# 45638  70ab2dbe1beab14c  2025.10.24  22:53:11  2.71e+03   1      0
# 45639  1c44e809f112078a  2025.10.24  22:53:58  1.58e+03   1      0
# 45641  7378375ee7bbf4a6  2025.10.24  22:59:47  6.10e+03   1      0
# 45642  5b0a9d95e9f6b568  2025.10.24  23:02:16  5.16e+03   1      0
# 45643  6c0483155e0f61ef  2025.10.24  23:03:18  1.36e+04   1      0
#
#       bitsPerSample srcLittleEndian dstLittleEndian dim    m stride  \
# 0                 8               0               0   1    2      1
# 1                 8               0               0   1    2      2
# 2                 8               0               0   1    2      3
# 3                 8               0               0   1    2      4
# 4                 8               0               0   1    2      5
# ...             ...             ...             ...  ..  ...    ...
# 45638            16               1               1   7   10      4
# 45639            16               1               1   8   10      2
# 45641            16               1               1   4  100      9
# 45642            16               1               1   5   10      8
# 45643            16               1               0   7   10      9
#
#                  N     Mtotal curtask Ntasks          sum              sum2  \
# 0               20          2       0      1           20               202
# 1               20          2       0      1           20               202
# 2               20          2       0      1           20               202
# 3               20          2       0      1           20               202
# 4               20          2       0      1           20               232
# ...            ...        ...     ...    ...          ...               ...
# 45638  10000000000   10000000       0      1  10000000000    10009998600608
# 45639  10000000000  100000000       0      1  10000000000     1009999040256
# 45641  10000000000  100000000       0      1  10000000000     1010002552634
# 45642  10000000000     100000       0      1  10000000000  1000010012285638
# 45643  10000000000   10000000       0      1  10000000000    10010002991746
#
#                      chi2cdf parameters_ok
# 0      3.452791539814230e-01             1
# 1      3.452791539814230e-01             1
# 2      3.452791539814230e-01             1
# 3      3.452791539814230e-01             1
# 4      9.263617298796973e-01             1
# ...                      ...           ...
# 45638  3.427989106621843e-01             1
# 45639  2.371519641002998e-01             1
# 45641  6.093118367817565e-01             1
# 45642  3.684624952247000e-01             1
# 45643  7.225993333332424e-01             1
#
# [41089 rows x 20 columns]

# %%
df_filtered.to_csv("../results_corr.csv", sep=' ', index=False)
