# %%
import pandas as pd
import numpy as np

# %%
dtype_spec = {"sum": np.int64, "sum2": np.int64, "chi2cdf": np.float64}
with open("../results_corr.csv", "r") as f:
    df = pd.read_csv(f, sep=" ", dtype=dtype_spec, keep_default_na=False, )
df
# Out:
#                   hash  rng  offset bitsPerSample  srcLittleEndian  \
# 0     166a320f22d7c6b2    1       0            16             True
# 1     10f5df379ce0ac39    1       0            16             True
# 2     1fbd7d92281713ca    1       0            16             True
# 3     072ce13c71ca6878    1       0            16             True
# 4     073c5a4db752edfe    1       0            16             True
# ...                ...  ...     ...           ...              ...
# 1890  4e4e1be81f543b4e    1       0          None             True
# 1891  04613ab928c6ac10    1       0             8             True
# 1892  4fc75e1a6abc368c    1       0             8             True
# 1893  0246f66103f77d85    1       0            16             True
# 1894  0bd9b42657d9acff    1       0            16             True
#
#       dstLittleEndian  dim    m          N  Mtot  curtask  Ntasks        sum  \
# 0                True    1    2         20     2        0       1         20
# ...

# %%
mask = (df.chi2cdf > 0.999)
df2 = df[mask].copy()
#df2
df2.groupby(["dim", "bitsPerSample"]).count()
# Out:
#                    hash  rng  offset  srcLittleEndian  dstLittleEndian    m  \
# dim bitsPerSample
# 1   16               59   59      59               59               59   59
#     8               150  150     150              150              150  150
# 2   16                4    4       4                4                4    4
#     8                57   57      57               57               57   57
# 3   8                28   28      28               28               28   28
# 4   8                18   18      18               18               18   18
# 5   8                11   11      11               11               11   11
# 6   8                 5    5       5                5                5    5
# 7   8                 4    4       4                4                4    4
#
#                      N  Mtot  curtask  Ntasks  sum  sum2  chi2cdf
# dim bitsPerSample
# 1   16              59    59       59      59   59    59       59
# ...

# %%
df.groupby(["dim", "bitsPerSample"]).count()
# Out:
#                    hash  rng  offset  srcLittleEndian  dstLittleEndian    m  \
# dim bitsPerSample
# 1   16              232  232     232              232              232  232
#     8               232  232     232              232              232  232
#     None            234  234     234              234              234  234
# 2   16              124  124     124              124              124  124
#     8               124  124     124              124              124  124
#     None            125  125     125              125              125  125
# 3   16               82   82      82               82               82   82
#     8                82   82      82               82               82   82
#     None             82   82      82               82               82   82
# 4   16               55   55      55               55               55   55
#     8                55   55      55               55               55   55
# ...

# %%
pivot = pd.pivot_table(df2, columns=["N"], index="dim", values="N")
pivot
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 pivot = pd.pivot_table(df2, columns=["N"], index="dim", values="N")
#       2 pivot
#
# File /usr/lib/python3/dist-packages/pandas/core/reshape/pivot.py:99, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      96     table = concat(pieces, keys=keys, axis=1)
#      97     return table.__finalize__(data, method="pivot_table")
# ---> 99 table = __internal_pivot_table(
#     100     data,
#     101     values,
#     102     index,
#     103     columns,
#     104     aggfunc,
#     105     fill_value,
#     106     margins,
#     107     dropna,
#     108     margins_name,
#     109     observed,
#     110     sort,
#     111 )
#     112 return table.__finalize__(data, method="pivot_table")
#
# ...
