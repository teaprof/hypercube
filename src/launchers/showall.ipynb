# %%
import pandas as pd
import numpy as np
import scipy

# %%
dtype_spec = {"sum": np.int64, "sum2": np.int64, "chi2cdf": np.float64, "parameters_ok": np.bool, "srcLittleEndian": np.bool, "dstLittleEndian": np.bool}
with open("../results.csv", "r") as f:
    df = pd.read_csv(f, sep="\s+", dtype=dtype_spec, keep_default_na=False)
df = df.drop(["hash","date","time","elapsed", "rng"], axis=1)
df
#df2 = df[(df.dim==1) & (df.m==2) & (df.stride==1) & (df.N==20)]
#df2
# Out:
#        offset  bitsPerSample  srcLittleEndian  dstLittleEndian  dim     m  \
# 0           0              0             True             True    1     2
# 1           0              0             True             True    1     2
# 2           0              0             True             True    1     4
# 3           0              0             True             True    2     2
# 4           0              0             True             True    2     2
# ...       ...            ...              ...              ...  ...   ...
# 21509       0             16             True            False    2    30
# 21510       0             16            False            False    2    30
# 21511       0             16            False            False    1  8192
# 21512       0             16            False            False    2    30
# 21513       0             16            False            False    2    30
#
#        stride         N  Mtotal  curtask  Ntasks       sum           sum2  \
# 0           1        20       2        0       1        20            200
# 1           1        40       2        0       1        40            808
# 2           1        40       4        0       1        40            406
# 3           2        40       4        0       1        40            410
# 4           1        40       4        0       1        40            412
# ...       ...       ...     ...      ...     ...       ...            ...
# 21509       7  90000000     900        0       1  90000000  9000084669202
# 21510       5  90000000     900        0       1  90000000  9000096196722
# 21511       7  81920000    8192        0       1  81920000   819283372852
# 21512       6  90000000     900        0       1  90000000  9000089208444
# 21513       7  90000000     900        0       1  90000000  9000091456546
#
#         chi2cdf  parameters_ok
# 0      0.000000           True
# 1      0.472911           True
# 2      0.103568           True
# 3      0.198748           True
# 4      0.246996           True
# ...         ...            ...
# 21509  0.107014           True
# 21510  0.928852           True
# 21511  0.873146           True
# 21512  0.441259           True
# 21513  0.648283           True
#
# [21514 rows x 15 columns]

# %%
alpha = 1e-6
mask = (df.chi2cdf > 1-alpha) & (df.parameters_ok == True)
df2 = df[mask].copy()
#df2
df2.groupby(["dim", "bitsPerSample", "parameters_ok", "srcLittleEndian", "dstLittleEndian", "stride"]).count()
# Out:
#                                                                         offset  \
# dim bitsPerSample parameters_ok srcLittleEndian dstLittleEndian stride
# 1   16            True          False           False           1            1
#                                                                 2            1
#                                                                 3            1
#                                                                 4            1
#                                                                 6            1
#                                                                 7            1
#                                                 True            2            1
#                                                                 3            1
#                                                                 5            1
#                                                                 7            1
#                                 True            False           2            1
#                                                                 3            1
#                                                                 4            1
#                                                                 6            1
#                                                                 7            1
#                                                 True            1            1
#                                                                 3            1
#                                                                 4            1
#                                                                 5            1
#                                                                 6            1
# 3   16            True          True            True            4            1
# 8   16            True          False           True            2            1
#                                 True            False           2            1
# 9   16            True          True            False           2            1
#
#                                                                         m  N  \
# dim bitsPerSample parameters_ok srcLittleEndian dstLittleEndian stride
# 1   16            True          False           False           1       1  1
#                                                                 2       1  1
#                                                                 3       1  1
#                                                                 4       1  1
#                                                                 6       1  1
#                                                                 7       1  1
#                                                 True            2       1  1
#                                                                 3       1  1
#                                                                 5       1  1
#                                                                 7       1  1
#                                 True            False           2       1  1
#                                                                 3       1  1
#                                                                 4       1  1
#                                                                 6       1  1
#                                                                 7       1  1
#                                                 True            1       1  1
#                                                                 3       1  1
#                                                                 4       1  1
#                                                                 5       1  1
#                                                                 6       1  1
# 3   16            True          True            True            4       1  1
# 8   16            True          False           True            2       1  1
#                                 True            False           2       1  1
# 9   16            True          True            False           2       1  1
#
#                                                                         Mtotal  \
# dim bitsPerSample parameters_ok srcLittleEndian dstLittleEndian stride
# 1   16            True          False           False           1            1
#                                                                 2            1
#                                                                 3            1
#                                                                 4            1
#                                                                 6            1
#                                                                 7            1
#                                                 True            2            1
#                                                                 3            1
#                                                                 5            1
#                                                                 7            1
#                                 True            False           2            1
#                                                                 3            1
#                                                                 4            1
#                                                                 6            1
#                                                                 7            1
#                                                 True            1            1
#                                                                 3            1
#                                                                 4            1
#                                                                 5            1
#                                                                 6            1
# 3   16            True          True            True            4            1
# 8   16            True          False           True            2            1
#                                 True            False           2            1
# 9   16            True          True            False           2            1
#
#                                                                         curtask  \
# dim bitsPerSample parameters_ok srcLittleEndian dstLittleEndian stride
# 1   16            True          False           False           1             1
#                                                                 2             1
#                                                                 3             1
#                                                                 4             1
#                                                                 6             1
#                                                                 7             1
#                                                 True            2             1
#                                                                 3             1
#                                                                 5             1
#                                                                 7             1
#                                 True            False           2             1
#                                                                 3             1
#                                                                 4             1
#                                                                 6             1
#                                                                 7             1
#                                                 True            1             1
#                                                                 3             1
#                                                                 4             1
#                                                                 5             1
#                                                                 6             1
# 3   16            True          True            True            4             1
# 8   16            True          False           True            2             1
#                                 True            False           2             1
# 9   16            True          True            False           2             1
#
#                                                                         Ntasks  \
# dim bitsPerSample parameters_ok srcLittleEndian dstLittleEndian stride
# 1   16            True          False           False           1            1
#                                                                 2            1
#                                                                 3            1
#                                                                 4            1
#                                                                 6            1
#                                                                 7            1
#                                                 True            2            1
#                                                                 3            1
#                                                                 5            1
#                                                                 7            1
#                                 True            False           2            1
#                                                                 3            1
#                                                                 4            1
#                                                                 6            1
#                                                                 7            1
#                                                 True            1            1
#                                                                 3            1
#                                                                 4            1
#                                                                 5            1
#                                                                 6            1
# 3   16            True          True            True            4            1
# 8   16            True          False           True            2            1
#                                 True            False           2            1
# 9   16            True          True            False           2            1
#
#                                                                         sum  \
# dim bitsPerSample parameters_ok srcLittleEndian dstLittleEndian stride
# 1   16            True          False           False           1         1
#                                                                 2         1
#                                                                 3         1
#                                                                 4         1
#                                                                 6         1
#                                                                 7         1
#                                                 True            2         1
#                                                                 3         1
#                                                                 5         1
#                                                                 7         1
#                                 True            False           2         1
#                                                                 3         1
#                                                                 4         1
#                                                                 6         1
#                                                                 7         1
#                                                 True            1         1
#                                                                 3         1
#                                                                 4         1
#                                                                 5         1
#                                                                 6         1
# 3   16            True          True            True            4         1
# 8   16            True          False           True            2         1
#                                 True            False           2         1
# 9   16            True          True            False           2         1
#
#                                                                         sum2  \
# dim bitsPerSample parameters_ok srcLittleEndian dstLittleEndian stride
# 1   16            True          False           False           1          1
#                                                                 2          1
#                                                                 3          1
#                                                                 4          1
#                                                                 6          1
#                                                                 7          1
#                                                 True            2          1
#                                                                 3          1
#                                                                 5          1
#                                                                 7          1
#                                 True            False           2          1
#                                                                 3          1
#                                                                 4          1
#                                                                 6          1
#                                                                 7          1
#                                                 True            1          1
#                                                                 3          1
#                                                                 4          1
#                                                                 5          1
#                                                                 6          1
# 3   16            True          True            True            4          1
# 8   16            True          False           True            2          1
#                                 True            False           2          1
# 9   16            True          True            False           2          1
#
#                                                                         chi2cdf
# dim bitsPerSample parameters_ok srcLittleEndian dstLittleEndian stride
# 1   16            True          False           False           1             1
#                                                                 2             1
#                                                                 3             1
#                                                                 4             1
#                                                                 6             1
#                                                                 7             1
#                                                 True            2             1
#                                                                 3             1
#                                                                 5             1
#                                                                 7             1
#                                 True            False           2             1
#                                                                 3             1
#                                                                 4             1
#                                                                 6             1
#                                                                 7             1
#                                                 True            1             1
#                                                                 3             1
#                                                                 4             1
#                                                                 5             1
#                                                                 6             1
# 3   16            True          True            True            4             1
# 8   16            True          False           True            2             1
#                                 True            False           2             1
# 9   16            True          True            False           2             1

# %%
mask = (df.chi2cdf > 1 - alpha) & (df.parameters_ok == True)
mask = np.flatnonzero(mask)
for idx in mask:
    row = df.iloc[idx]
#dof = row["Mtotal"]-1
#sum = row["sum"]
#mean = row["sum"]/(dof+1)
#sum2 = row["sum2"]
#chi2 = sum2/mean - sum
#chi2cdf = scipy.stats.chi2.cdf(chi2, dof)
    print(f"idx = {idx}, chi2cdf = {row['chi2cdf']}")
df.iloc[mask]
# Out:
# idx = 4593, chi2cdf = 0.9999999999795346
# idx = 4627, chi2cdf = 0.9999999999795346
# idx = 11484, chi2cdf = 0.9999997852167596
# idx = 11523, chi2cdf = 0.9999997852167596
# idx = 11528, chi2cdf = 0.9999998190086824
# idx = 18664, chi2cdf = 0.9999991447081206
# idx = 20902, chi2cdf = 0.9999999989970232
# idx = 20908, chi2cdf = 0.9999999999978216
# idx = 20909, chi2cdf = 0.999999999532462
# idx = 20918, chi2cdf = 0.9999999999999644
# idx = 20926, chi2cdf = 0.9999999977854126
# idx = 20931, chi2cdf = 0.9999999855413008
# idx = 20932, chi2cdf = 0.9999999978820128
# idx = 20933, chi2cdf = 0.9999999141724792
# idx = 20934, chi2cdf = 0.9999999126914892
# idx = 20945, chi2cdf = 0.9999999999909842
# idx = 20949, chi2cdf = 0.999999999965475
# idx = 20954, chi2cdf = 0.9999998781826372
# idx = 20983, chi2cdf = 0.9999999999370838
# idx = 20990, chi2cdf = 0.9999999999342748
# idx = 21006, chi2cdf = 0.9999999941356996
# idx = 21025, chi2cdf = 0.9999999999859182
# idx = 21061, chi2cdf = 0.9999993956196096
# idx = 21084, chi2cdf = 0.9999999996340546
#        offset  bitsPerSample  srcLittleEndian  dstLittleEndian  dim    m  \
# 4593        0             16             True             True    1  500
# 4627        0             16            False            False    1  500
# 11484       0             16            False             True    8    2
# 11523       0             16             True            False    8    2
# 11528       0             16             True            False    9    2
# 18664       0             16             True             True    3    4
# 20902       0             16             True             True    1  500
# 20908       0             16             True             True    1  500
# 20909       0             16            False             True    1  500
# 20918       0             16             True            False    1  500
# 20926       0             16             True             True    1  500
# 20931       0             16             True             True    1  500
# 20932       0             16            False            False    1  500
# 20933       0             16            False             True    1  500
# 20934       0             16             True            False    1  500
# 20945       0             16             True            False    1  500
# 20949       0             16            False            False    1  500
# 20954       0             16            False             True    1  500
# 20983       0             16            False            False    1  500
# 20990       0             16             True            False    1  500
# 21006       0             16            False             True    1  500
# 21025       0             16             True            False    1  500
# 21061       0             16            False            False    1  500
# 21084       0             16            False            False    1  500
#
#        stride         N  Mtotal  curtask  Ntasks       sum           sum2  \
# 4593        1  50000000     500        0       1  50000000  5000073669404
# 4627        1  50000000     500        0       1  50000000  5000073669404
# 11484       2     25600     256        0       1     25600        2598596
# 11523       2     25600     256        0       1     25600        2598596
# 11528       2     25600     512        0       1     25600        1314528
# 18664       4   6400000      64        0       1   6400000   640013193954
# 20902       3  50000000     500        0       1  50000000  5000071234614
# 20908       4  50000000     500        0       1  50000000  5000075000572
# 20909       2  50000000     500        0       1  50000000  5000071725854
# 20918       2  50000000     500        0       1  50000000  5000077334470
# 20926       5  50000000     500        0       1  50000000  5000070716864
# 20931       6  50000000     500        0       1  50000000  5000069455108
# 20932       2  50000000     500        0       1  50000000  5000070746240
# 20933       3  50000000     500        0       1  50000000  5000068205136
# 20934       3  50000000     500        0       1  50000000  5000068192854
# 20945       4  50000000     500        0       1  50000000  5000074161884
# 20949       3  50000000     500        0       1  50000000  5000073351810
# 20954       5  50000000     500        0       1  50000000  5000067952624
# 20983       4  50000000     500        0       1  50000000  5000072983922
# 20990       6  50000000     500        0       1  50000000  5000072957000
# 21006       7  50000000     500        0       1  50000000  5000070068486
# 21025       7  50000000     500        0       1  50000000  5000073894798
# 21061       6  50000000     500        0       1  50000000  5000066765722
# 21084       7  50000000     500        0       1  50000000  5000071882016
#
#         chi2cdf  parameters_ok
# 4593   1.000000           True
# 4627   1.000000           True
# 11484  1.000000           True
# 11523  1.000000           True
# 11528  1.000000           True
# 18664  0.999999           True
# 20902  1.000000           True
# 20908  1.000000           True
# 20909  1.000000           True
# 20918  1.000000           True
# 20926  1.000000           True
# 20931  1.000000           True
# 20932  1.000000           True
# 20933  1.000000           True
# 20934  1.000000           True
# 20945  1.000000           True
# 20949  1.000000           True
# 20954  1.000000           True
# 20983  1.000000           True
# 20990  1.000000           True
# 21006  1.000000           True
# 21025  1.000000           True
# 21061  0.999999           True
# 21084  1.000000           True
