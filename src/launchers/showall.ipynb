# %%
import pandas as pd
import numpy as np
import scipy

# %%
dtype_spec = {"sum": np.int64, "sum2": np.int64, "chi2cdf": np.float64, "parameters_ok": np.bool, "srcLittleEndian": np.bool, "dstLittleEndian": np.bool}
with open("../results.csv", "r") as f:
    df = pd.read_csv(f, sep="\s+", dtype=dtype_spec, keep_default_na=False)
df = df.drop(["hash","date","time","elapsed", "rng", "srcLittleEndian", "dstLittleEndian"], axis=1)
df
# Out:
#       offset  bitsPerSample  dim     m  stride         N   Mtotal  curtask  \
# 0          0              8    1     2       1        20        2        0
# 1          0             16    1     2       1        20        2        0
# 2          0              0    1     2       1        20        2        0
# 3          0              8    1     2       1        40        2        0
# 4          0              8    1     4       1        40        4        0
# ...      ...            ...  ...   ...     ...       ...      ...      ...
# 1816       0              0    2  2048       2  83886080  4194304        0
# 1817       0              0    3   200       3  80000000  8000000        0
# 1818       0             16    6     2       6  64000000       64        0
# 1819       0             16    8     4       8  65536000    65536        0
# 1820       0              0   11     4      11  83886080  4194304        0
#
#       Ntasks       sum            sum2   chi2cdf  parameters_ok
# ...

# %%
mask = (df.chi2cdf > 0.9999)
df2 = df[mask].copy()
#df2
df2.groupby(["dim", "bitsPerSample", "parameters_ok"]).count()
# Out:
#                                  offset   m  stride   N  Mtotal  curtask  \
# dim bitsPerSample parameters_ok
# 1   8             False              27  27      27  27      27       27
#     16            False               7   7       7   7       7        7
#                   True                1   1       1   1       1        1
# 2   8             False               6   6       6   6       6        6
#
#                                  Ntasks  sum  sum2  chi2cdf
# dim bitsPerSample parameters_ok
# 1   8             False              27   27    27       27
#     16            False               7    7     7        7
#                   True                1    1     1        1
# 2   8             False               6    6     6        6

# %%
mask = ((df.dim == 1) & (df.bitsPerSample == 16) & (df.chi2cdf > 0.9999) & (df.parameters_ok == True))
mask = np.flatnonzero(mask)
row = df.iloc[mask[0]]
#dof = row["Mtotal"]-1
#sum = row["sum"]
#mean = row["sum"]/(dof+1)
#sum2 = row["sum2"]
#chi2 = sum2/mean - sum
#chi2cdf = scipy.stats.chi2.cdf(chi2, dof)
row["chi2cdf"]
# Out:
# np.float64(2.0465407146730286e-11)

# %%
df.groupby(["dim", "bitsPerSample"]).count()
# Out:
#                    offset    m  stride    N  Mtotal  curtask  Ntasks  sum  \
# dim bitsPerSample
# 1   0                 199  199     199  199     199      199     199  199
#     8                 108  108     108  108     108      108     108  108
#     16                172  172     172  172     172      172     172  172
# 2   0                 212  212     212  212     212      212     212  212
#     8                  76   76      76   76      76       76      76   76
#     16                180  180     180  180     180      180     180  180
# 3   0                 132  132     132  132     132      132     132  132
#     8                  32   32      32   32      32       32      32   32
#     16                112  112     112  112     112      112     112  112
# 4   0                  88   88      88   88      88       88      88   88
#     8                  30   30      30   30      30       30      30   30
# ...

# %%
pivot = pd.pivot_table(df2, columns=["N"], index="dim", values="N")
pivot
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 pivot = pd.pivot_table(df2, columns=["N"], index="dim", values="N")
#       2 pivot
#
# File ~/myprojects/hypercube/.venv/lib/python3.10/site-packages/pandas/core/reshape/pivot.py:102, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      99     table = concat(pieces, keys=keys, axis=1)
#     100     return table.__finalize__(data, method="pivot_table")
# --> 102 table = __internal_pivot_table(
#     103     data,
#     104     values,
#     105     index,
#     106     columns,
#     107     aggfunc,
#     108     fill_value,
#     109     margins,
#     110     dropna,
#     111     margins_name,
#     112     observed,
#     113     sort,
#     114 )
#     115 return table.__finalize__(data, method="pivot_table")
#
# ...
