# %%
import pandas as pd
import numpy as np

# %%
dtype_spec = {"sum": int, "sum2:", int, "chi2cdf": float}
with open("../results_corr.csv", "r") as f:
    df = pd.read_csv(f, sep=" ", dtype=dtype_spec, keep_default_na=False)
df.chi2cdf = df.chi2cdf.astype(float)
df
# Out:
#             Unnamed: 0  Unnamed: 1  Unnamed: 2  hash   rng  offset  dim  \
# 0     166a320f22d7c6b2           1           0    16  True    True    1
# 1     10f5df379ce0ac39           1           0    16  True    True    1
# 2     1fbd7d92281713ca           1           0    16  True    True    1
# 3     072ce13c71ca6878           1           0    16  True    True    2
# 4     073c5a4db752edfe           1           0    16  True    True    1
# ...                ...         ...         ...   ...   ...     ...  ...
# 1211  27329242d53b509b           1           0     8  True    True    1
# 1212  34760d8ddbc483d0           1           0     8  True    True    8
# 1213  1bb7a613cc5016b8           1           0     8  True    True    5
# 1214  124cc7eb10d12fdc           1           0     8  True    True    8
# 1215  1577d8fb7b7c2967           1           0     8  True    True    2
#
#              m          N      Mtot  curtask  Ntasks        sum  \
# ...

# %%
mask = (df.chi2cdf > 1 - 1e-9)
df2 = df[mask]
df2['chi2cdf'] = df2['chi2cdf'] - 1
df2
# Out:
# /tmp/ipykernel_17679/3687342491.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['chi2cdf'] = df2['chi2cdf'] - 1
#             Unnamed: 0  Unnamed: 1  Unnamed: 2  hash   rng  offset  dim  \
# 220   05882c25125b29cc           1           0    16  True    True    1
# 257   4d443ef22fb1390e           1           0    16  True    True    1
# 288   010a02897c06eb7c           1           0    16  True    True    1
# 289   1286a8fa68be860d           1           0    16  True    True    1
# 302   17472a1f738d9489           1           0    16  True    True    1
# ...                ...         ...         ...   ...   ...     ...  ...
# 1200  12dafe024e042eee           1           0     8  True    True    1
# ...
