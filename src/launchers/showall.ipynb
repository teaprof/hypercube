# %%
import pandas as pd
import numpy as np
import scipy

# %%
dtype_spec = {"sum": np.int64, "sum2": np.int64, "chi2cdf": np.float64, "parameters_ok": np.bool, "srcLittleEndian": np.bool, "dstLittleEndian": np.bool}
with open("../results.csv", "r") as f:
    df = pd.read_csv(f, sep="\s+", dtype=dtype_spec, keep_default_na=False)
df = df.drop(["date","time","elapsed", "rng"], axis=1)
df
#df2 = df[(df.dim==1) & (df.m==2) & (df.stride==1) & (df.N==20)]
#df2
# Out:
#                    hash  offset  bitsPerSample  srcLittleEndian  \
# 0      2328d7d51b69aa46       0              8            False
# 1      0bf5c7b73b605c41       0              8            False
# 2      06c5f05cc73e5e3a       0              8            False
# 3      1de1446a8bca2727       0              8            False
# 4      4b5b77d57216a95a       0              8            False
# ...                 ...     ...            ...              ...
# 38000  0719e3bb1fe376b6       0              0             True
# 38001  7f8e696b7fa6fcc5       0              0             True
# 38002  0d18cf00e4d1e84e       0              0             True
# 38003  010598de2a052851       0              0             True
# 38004  678485c73f02de6a       0              0             True
#
#        dstLittleEndian  dim        m  stride            N      Mtotal  \
# 0                False    1        2       1           20           2
# 1                False    1        2       2           20           2
# 2                False    1        2       3           20           2
# 3                False    1        2       4           20           2
# 4                False    1        2       5           20           2
# ...                ...  ...      ...     ...          ...         ...
# 38000             True    1  8388608       9  83886080000     8388608
# 38001             True    6       40       7  81920000000  4096000000
# 38002             True    6       40       6  81920000000  4096000000
# 38003             True    6       40       1  81920000000  4096000000
# 38004             True    6       40       5  81920000000  4096000000
#
#        curtask  Ntasks          sum             sum2   chi2cdf  parameters_ok
# 0            0       1           20              202  0.345279           True
# 1            0       1           20              202  0.345279           True
# 2            0       1           20              202  0.345279           True
# 3            0       1           20              202  0.345279           True
# 4            0       1           20              232  0.926362           True
# ...        ...     ...          ...              ...       ...            ...
# 38000        0       1  83886080000  838944679198024  0.433443           True
# 38001        0       1  81920000000    1720320539390  0.617241           True
# 38002        0       1  81920000000    1720320755744  0.661939           True
# 38003        0       1  81920000000    1720319137538  0.316973           True
# 38004        0       1  81920000000    1720321474230  0.792369           True
#
# [38005 rows x 16 columns]

# %%
alpha = 1e-6
mask = (df.chi2cdf > 1-alpha) & (df.parameters_ok == True)
df2 = df[mask].copy()
df2.insert(10, 'n per cell', df2.N/df2.Mtotal)
#df2
df2.groupby(["dim", "bitsPerSample", "parameters_ok", "srcLittleEndian", "dstLittleEndian", "stride"]).count()
# Out:
#                                                                         hash  \
# dim bitsPerSample parameters_ok srcLittleEndian dstLittleEndian stride
# 1   0             True          True            True            0        295
#     8             True          False           False           0         63
#                                                 True            0         63
#                                 True            False           0         63
#                                                 True            0         63
# ...                                                                      ...
# 11  0             True          True            True            0         14
#     16            True          False           False           0          8
#                                                 True            0          8
#                                 True            False           0          8
#                                                 True            0          8
#
#                                                                         offset  \
# dim bitsPerSample parameters_ok srcLittleEndian dstLittleEndian stride
# 1   0             True          True            True            0          295
#     8             True          False           False           0           63
#                                                 True            0           63
#                                 True            False           0           63
#                                                 True            0           63
# ...                                                                        ...
# 11  0             True          True            True            0           14
#     16            True          False           False           0            8
#                                                 True            0            8
#                                 True            False           0            8
#                                                 True            0            8
#
#                                                                           m  \
# dim bitsPerSample parameters_ok srcLittleEndian dstLittleEndian stride
# 1   0             True          True            True            0       295
#     8             True          False           False           0        63
#                                                 True            0        63
#                                 True            False           0        63
#                                                 True            0        63
# ...                                                                     ...
# 11  0             True          True            True            0        14
#     16            True          False           False           0         8
#                                                 True            0         8
#                                 True            False           0         8
#                                                 True            0         8
#
#                                                                           N  \
# dim bitsPerSample parameters_ok srcLittleEndian dstLittleEndian stride
# 1   0             True          True            True            0       295
#     8             True          False           False           0        63
#                                                 True            0        63
#                                 True            False           0        63
#                                                 True            0        63
# ...                                                                     ...
# 11  0             True          True            True            0        14
#     16            True          False           False           0         8
#                                                 True            0         8
#                                 True            False           0         8
#                                                 True            0         8
#
#                                                                         Mtotal  \
# dim bitsPerSample parameters_ok srcLittleEndian dstLittleEndian stride
# 1   0             True          True            True            0          295
#     8             True          False           False           0           63
#                                                 True            0           63
#                                 True            False           0           63
#                                                 True            0           63
# ...                                                                        ...
# 11  0             True          True            True            0           14
#     16            True          False           False           0            8
#                                                 True            0            8
#                                 True            False           0            8
#                                                 True            0            8
#
#                                                                         n per cell  \
# dim bitsPerSample parameters_ok srcLittleEndian dstLittleEndian stride
# 1   0             True          True            True            0              295
#     8             True          False           False           0               63
#                                                 True            0               63
#                                 True            False           0               63
#                                                 True            0               63
# ...                                                                            ...
# 11  0             True          True            True            0               14
#     16            True          False           False           0                8
#                                                 True            0                8
#                                 True            False           0                8
#                                                 True            0                8
#
#                                                                         curtask  \
# dim bitsPerSample parameters_ok srcLittleEndian dstLittleEndian stride
# 1   0             True          True            True            0           295
#     8             True          False           False           0            63
#                                                 True            0            63
#                                 True            False           0            63
#                                                 True            0            63
# ...                                                                         ...
# 11  0             True          True            True            0            14
#     16            True          False           False           0             8
#                                                 True            0             8
#                                 True            False           0             8
#                                                 True            0             8
#
#                                                                         Ntasks  \
# dim bitsPerSample parameters_ok srcLittleEndian dstLittleEndian stride
# 1   0             True          True            True            0          295
#     8             True          False           False           0           63
#                                                 True            0           63
#                                 True            False           0           63
#                                                 True            0           63
# ...                                                                        ...
# 11  0             True          True            True            0           14
#     16            True          False           False           0            8
#                                                 True            0            8
#                                 True            False           0            8
#                                                 True            0            8
#
#                                                                         sum  \
# dim bitsPerSample parameters_ok srcLittleEndian dstLittleEndian stride
# 1   0             True          True            True            0       295
#     8             True          False           False           0        63
#                                                 True            0        63
#                                 True            False           0        63
#                                                 True            0        63
# ...                                                                     ...
# 11  0             True          True            True            0        14
#     16            True          False           False           0         8
#                                                 True            0         8
#                                 True            False           0         8
#                                                 True            0         8
#
#                                                                         sum2  \
# dim bitsPerSample parameters_ok srcLittleEndian dstLittleEndian stride
# 1   0             True          True            True            0        295
#     8             True          False           False           0         63
#                                                 True            0         63
#                                 True            False           0         63
#                                                 True            0         63
# ...                                                                      ...
# 11  0             True          True            True            0         14
#     16            True          False           False           0          8
#                                                 True            0          8
#                                 True            False           0          8
#                                                 True            0          8
#
#                                                                         chi2cdf
# dim bitsPerSample parameters_ok srcLittleEndian dstLittleEndian stride
# 1   0             True          True            True            0           295
#     8             True          False           False           0            63
#                                                 True            0            63
#                                 True            False           0            63
#                                                 True            0            63
# ...                                                                         ...
# 11  0             True          True            True            0            14
#     16            True          False           False           0             8
#                                                 True            0             8
#                                 True            False           0             8
#                                                 True            0             8
#
# [91 rows x 11 columns]

# %%
df2
# Out:
#                    hash  offset  bitsPerSample  srcLittleEndian  \
# 8511   01701bf8635b2095       0             16            False
# 8564   708a5474d5bf9cf8       0             16             True
# 8572   1f839344d1585d48       0             16             True
# 17821  0d45f80a53c46f18       0             16             True
# 23205  058cad01a53ca801       0              8            False
# ...                 ...     ...            ...              ...
# 37926  699568eaf77c0227       0              0             True
# 37935  1a40f73191b1b194       0              0             True
# 37946  0c65aef169d703b1       0              0             True
# 37952  78dd53d98f1bcf8a       0              0             True
# 37973  44eb9a12378d04f5       0              0             True
#
#        dstLittleEndian  dim        m  stride            N      Mtotal  \
# 8511              True    8        2       2        25600         256
# 8564             False    8        2       2        25600         256
# 8572             False    9        2       2        25600         512
# 17821             True    3        4       4      6400000          64
# 23205            False    1        2       0           40           2
# ...                ...  ...      ...     ...          ...         ...
# 37926             True    6       30       0  72900000000   729000000
# 37935             True    3      200       0  80000000000     8000000
# 37946             True    4      200       0  80000000000  1600000000
# 37952             True    4       30       0  81000000000      810000
# 37973             True    1  8388608       0  83886080000     8388608
#
#        n per cell  curtask  Ntasks          sum                  sum2  \
# 8511        100.0        0       1        25600               2598596
# 8564        100.0        0       1        25600               2598596
# 8572         50.0        0       1        25600               1314528
# 17821    100000.0        0       1      6400000          640013193954
# 23205        20.0        0       1           40                  1600
# ...           ...      ...     ...          ...                   ...
# 37926       100.0        0       1  72900000000   1747706771649134592
# 37935     10000.0        0       1  80000000000  17426550496495140864
# 37946        50.0        0       1  80000000000  17426550496495140864
# 37952    100000.0        0       1  81000000000  12405853833109176320
# 37973     10000.0        0       1  83886080000   8664925683060834304
#
#         chi2cdf  parameters_ok
# 8511   1.000000           True
# 8564   1.000000           True
# 8572   1.000000           True
# 17821  0.999999           True
# 23205  1.000000           True
# ...         ...            ...
# 37926  1.000000           True
# 37935  1.000000           True
# 37946  1.000000           True
# 37952  1.000000           True
# 37973  1.000000           True
#
# [3504 rows x 17 columns]

# %%
mask = ((df.chi2cdf > 1 - alpha)) & (df.parameters_ok == True)
mask = np.flatnonzero(mask)
for idx in mask:
    row = df.iloc[idx]
#dof = row["Mtotal"]-1
#sum = row["sum"]
#mean = row["sum"]/(dof+1)
#sum2 = row["sum2"]
#chi2 = sum2/mean - sum
#chi2cdf = scipy.stats.chi2.cdf(chi2, dof)
    print(f"idx = {idx}, chi2cdf = {row['chi2cdf']}")
df.iloc[mask]
# Out:
# idx = 8511, chi2cdf = 0.9999997852167596
# idx = 8564, chi2cdf = 0.9999997852167596
# idx = 8572, chi2cdf = 0.9999998190086824
# idx = 17821, chi2cdf = 0.9999991447081206
# idx = 23205, chi2cdf = 0.9999999997460371
# idx = 23206, chi2cdf = 1.0
# idx = 23207, chi2cdf = 1.0
# idx = 23208, chi2cdf = 0.9999999997460371
# idx = 23209, chi2cdf = 1.0
# idx = 23210, chi2cdf = 1.0
# idx = 23211, chi2cdf = 0.9999999997460371
# idx = 23212, chi2cdf = 1.0
# idx = 23213, chi2cdf = 1.0
# idx = 23214, chi2cdf = 0.9999999997460371
# idx = 23215, chi2cdf = 1.0
# idx = 23216, chi2cdf = 1.0
# idx = 23217, chi2cdf = 0.9999999997460371
# idx = 23218, chi2cdf = 1.0
# idx = 23219, chi2cdf = 1.0
# idx = 23220, chi2cdf = 0.9999999997460371
# idx = 23221, chi2cdf = 1.0
# idx = 23222, chi2cdf = 1.0
# idx = 23223, chi2cdf = 0.9999999997460371
# idx = 23224, chi2cdf = 1.0
# idx = 23225, chi2cdf = 1.0
# idx = 23226, chi2cdf = 0.9999999997460371
# idx = 23227, chi2cdf = 1.0
# idx = 23228, chi2cdf = 1.0
# idx = 23229, chi2cdf = 0.9999999997460371
# idx = 23230, chi2cdf = 1.0
# idx = 23231, chi2cdf = 1.0
# idx = 23232, chi2cdf = 1.0
# idx = 23233, chi2cdf = 1.0
# idx = 23234, chi2cdf = 1.0
# idx = 23235, chi2cdf = 1.0
# idx = 23236, chi2cdf = 1.0
# idx = 23237, chi2cdf = 1.0
# idx = 23238, chi2cdf = 1.0
# idx = 23239, chi2cdf = 1.0
# idx = 23240, chi2cdf = 1.0
# idx = 23241, chi2cdf = 1.0
# idx = 23242, chi2cdf = 1.0
# idx = 23243, chi2cdf = 1.0
# idx = 23244, chi2cdf = 1.0
# idx = 23245, chi2cdf = 1.0
# idx = 23246, chi2cdf = 1.0
# idx = 23247, chi2cdf = 1.0
# idx = 23248, chi2cdf = 1.0
# idx = 23249, chi2cdf = 1.0
# idx = 23250, chi2cdf = 1.0
# idx = 23251, chi2cdf = 1.0
# idx = 23252, chi2cdf = 1.0
# idx = 23253, chi2cdf = 1.0
# idx = 23254, chi2cdf = 1.0
# idx = 23255, chi2cdf = 1.0
# idx = 23256, chi2cdf = 1.0
# idx = 23257, chi2cdf = 1.0
# idx = 23258, chi2cdf = 1.0
# idx = 23259, chi2cdf = 1.0
# idx = 23260, chi2cdf = 1.0
# idx = 23261, chi2cdf = 1.0
# idx = 23262, chi2cdf = 1.0
# idx = 23263, chi2cdf = 1.0
# idx = 23264, chi2cdf = 1.0
# idx = 23265, chi2cdf = 1.0
# idx = 23266, chi2cdf = 1.0
# idx = 23267, chi2cdf = 1.0
# idx = 23269, chi2cdf = 1.0
# idx = 23271, chi2cdf = 1.0
# idx = 23273, chi2cdf = 1.0
# idx = 23275, chi2cdf = 1.0
# idx = 23276, chi2cdf = 1.0
# idx = 23277, chi2cdf = 1.0
# idx = 23278, chi2cdf = 1.0
# idx = 23279, chi2cdf = 1.0
# idx = 23280, chi2cdf = 1.0
# idx = 23281, chi2cdf = 1.0
# idx = 23282, chi2cdf = 1.0
# idx = 23283, chi2cdf = 1.0
# idx = 23284, chi2cdf = 1.0
# idx = 23285, chi2cdf = 1.0
# idx = 23286, chi2cdf = 1.0
# idx = 23287, chi2cdf = 1.0
# idx = 23288, chi2cdf = 1.0
# idx = 23289, chi2cdf = 1.0
# idx = 23290, chi2cdf = 1.0
# idx = 23291, chi2cdf = 1.0
# idx = 23292, chi2cdf = 1.0
# idx = 23293, chi2cdf = 1.0
# idx = 23294, chi2cdf = 1.0
# idx = 23295, chi2cdf = 1.0
# idx = 23296, chi2cdf = 1.0
# idx = 23297, chi2cdf = 1.0
# idx = 23298, chi2cdf = 1.0
# idx = 23299, chi2cdf = 1.0
# idx = 23300, chi2cdf = 1.0
# idx = 23301, chi2cdf = 1.0
# idx = 23302, chi2cdf = 1.0
# idx = 23303, chi2cdf = 1.0
# idx = 23304, chi2cdf = 1.0
# idx = 23305, chi2cdf = 1.0
# idx = 23306, chi2cdf = 1.0
# idx = 23307, chi2cdf = 1.0
# idx = 23308, chi2cdf = 1.0
# idx = 23309, chi2cdf = 1.0
# idx = 23310, chi2cdf = 1.0
# idx = 23311, chi2cdf = 1.0
# idx = 23312, chi2cdf = 1.0
# idx = 23313, chi2cdf = 1.0
# idx = 23314, chi2cdf = 1.0
# idx = 23315, chi2cdf = 1.0
# idx = 23316, chi2cdf = 1.0
# idx = 23317, chi2cdf = 1.0
# idx = 23318, chi2cdf = 1.0
# idx = 23319, chi2cdf = 1.0
# idx = 23320, chi2cdf = 1.0
# idx = 23321, chi2cdf = 1.0
# idx = 23322, chi2cdf = 1.0
# idx = 23323, chi2cdf = 1.0
# idx = 23324, chi2cdf = 1.0
# idx = 23325, chi2cdf = 1.0
# idx = 23326, chi2cdf = 1.0
# idx = 23327, chi2cdf = 1.0
# idx = 23328, chi2cdf = 1.0
# idx = 23329, chi2cdf = 1.0
# idx = 23330, chi2cdf = 1.0
# idx = 23333, chi2cdf = 1.0
# idx = 23334, chi2cdf = 1.0
# idx = 23335, chi2cdf = 1.0
# idx = 23338, chi2cdf = 1.0
# idx = 23339, chi2cdf = 1.0
# idx = 23340, chi2cdf = 1.0
# idx = 23343, chi2cdf = 1.0
# idx = 23344, chi2cdf = 1.0
# idx = 23345, chi2cdf = 1.0
# idx = 23348, chi2cdf = 1.0
# idx = 23349, chi2cdf = 1.0
# idx = 23350, chi2cdf = 1.0
# idx = 23351, chi2cdf = 1.0
# idx = 23352, chi2cdf = 1.0
# idx = 23353, chi2cdf = 1.0
# idx = 23354, chi2cdf = 1.0
# idx = 23355, chi2cdf = 1.0
# idx = 23356, chi2cdf = 1.0
# idx = 23357, chi2cdf = 1.0
# idx = 23358, chi2cdf = 1.0
# idx = 23359, chi2cdf = 1.0
# idx = 23360, chi2cdf = 1.0
# idx = 23361, chi2cdf = 1.0
# idx = 23362, chi2cdf = 1.0
# idx = 23363, chi2cdf = 1.0
# idx = 23364, chi2cdf = 1.0
# idx = 23365, chi2cdf = 1.0
# idx = 23366, chi2cdf = 1.0
# idx = 23367, chi2cdf = 1.0
# idx = 23368, chi2cdf = 1.0
# idx = 23369, chi2cdf = 1.0
# idx = 23370, chi2cdf = 1.0
# idx = 23371, chi2cdf = 1.0
# idx = 23372, chi2cdf = 1.0
# idx = 23373, chi2cdf = 1.0
# idx = 23374, chi2cdf = 1.0
# idx = 23375, chi2cdf = 1.0
# idx = 23380, chi2cdf = 1.0
# idx = 23381, chi2cdf = 1.0
# idx = 23382, chi2cdf = 1.0
# idx = 23383, chi2cdf = 1.0
# idx = 23384, chi2cdf = 1.0
# idx = 23385, chi2cdf = 1.0
# idx = 23386, chi2cdf = 1.0
# idx = 23387, chi2cdf = 1.0
# idx = 23388, chi2cdf = 1.0
# idx = 23389, chi2cdf = 1.0
# idx = 23390, chi2cdf = 1.0
# idx = 23391, chi2cdf = 1.0
# idx = 23392, chi2cdf = 1.0
# idx = 23393, chi2cdf = 1.0
# idx = 23394, chi2cdf = 1.0
# idx = 23395, chi2cdf = 1.0
# idx = 23396, chi2cdf = 1.0
# idx = 23397, chi2cdf = 1.0
# idx = 23398, chi2cdf = 1.0
# idx = 23399, chi2cdf = 1.0
# idx = 23400, chi2cdf = 1.0
# idx = 23401, chi2cdf = 1.0
# idx = 23402, chi2cdf = 1.0
# idx = 23403, chi2cdf = 1.0
# idx = 23404, chi2cdf = 1.0
# idx = 23405, chi2cdf = 1.0
# idx = 23406, chi2cdf = 1.0
# idx = 23407, chi2cdf = 1.0
# idx = 23408, chi2cdf = 1.0
# idx = 23409, chi2cdf = 1.0
# idx = 23410, chi2cdf = 1.0
# idx = 23411, chi2cdf = 1.0
# idx = 23412, chi2cdf = 1.0
# idx = 23413, chi2cdf = 1.0
# idx = 23414, chi2cdf = 1.0
# idx = 23415, chi2cdf = 1.0
# idx = 23416, chi2cdf = 1.0
# idx = 23417, chi2cdf = 1.0
# idx = 23418, chi2cdf = 1.0
# idx = 23419, chi2cdf = 1.0
# idx = 23420, chi2cdf = 1.0
# idx = 23421, chi2cdf = 1.0
# idx = 23422, chi2cdf = 1.0
# idx = 23423, chi2cdf = 1.0
# idx = 23424, chi2cdf = 1.0
# idx = 23425, chi2cdf = 1.0
# idx = 23426, chi2cdf = 1.0
# idx = 23427, chi2cdf = 1.0
# idx = 23428, chi2cdf = 1.0
# idx = 23429, chi2cdf = 1.0
# idx = 23432, chi2cdf = 1.0
# idx = 23433, chi2cdf = 1.0
# idx = 23434, chi2cdf = 1.0
# idx = 23435, chi2cdf = 1.0
# idx = 23438, chi2cdf = 1.0
# idx = 23439, chi2cdf = 1.0
# idx = 23440, chi2cdf = 1.0
# idx = 23441, chi2cdf = 1.0
# idx = 23444, chi2cdf = 1.0
# idx = 23445, chi2cdf = 1.0
# idx = 23446, chi2cdf = 1.0
# idx = 23447, chi2cdf = 1.0
# idx = 23450, chi2cdf = 1.0
# idx = 23451, chi2cdf = 1.0
# idx = 23452, chi2cdf = 1.0
# idx = 23453, chi2cdf = 1.0
# idx = 23454, chi2cdf = 1.0
# idx = 23455, chi2cdf = 1.0
# idx = 23456, chi2cdf = 1.0
# idx = 23457, chi2cdf = 1.0
# idx = 23458, chi2cdf = 1.0
# idx = 23459, chi2cdf = 1.0
# idx = 23460, chi2cdf = 1.0
# idx = 23461, chi2cdf = 1.0
# idx = 23462, chi2cdf = 1.0
# idx = 23463, chi2cdf = 1.0
# idx = 23464, chi2cdf = 1.0
# idx = 23465, chi2cdf = 1.0
# idx = 23466, chi2cdf = 1.0
# idx = 23467, chi2cdf = 1.0
# idx = 23468, chi2cdf = 1.0
# idx = 23469, chi2cdf = 1.0
# idx = 23470, chi2cdf = 1.0
# idx = 23471, chi2cdf = 1.0
# idx = 23472, chi2cdf = 1.0
# idx = 23473, chi2cdf = 1.0
# idx = 23474, chi2cdf = 1.0
# idx = 23475, chi2cdf = 1.0
# idx = 23476, chi2cdf = 1.0
# idx = 23477, chi2cdf = 1.0
# idx = 23478, chi2cdf = 1.0
# idx = 23479, chi2cdf = 1.0
# idx = 23480, chi2cdf = 1.0
# idx = 23481, chi2cdf = 1.0
# idx = 23482, chi2cdf = 1.0
# idx = 23483, chi2cdf = 1.0
# idx = 23488, chi2cdf = 1.0
# idx = 23489, chi2cdf = 1.0
# idx = 23490, chi2cdf = 1.0
# idx = 23491, chi2cdf = 1.0
# idx = 23492, chi2cdf = 1.0
# idx = 23497, chi2cdf = 1.0
# idx = 23498, chi2cdf = 1.0
# idx = 23499, chi2cdf = 1.0
# idx = 23500, chi2cdf = 1.0
# idx = 23501, chi2cdf = 1.0
# idx = 23502, chi2cdf = 1.0
# idx = 23503, chi2cdf = 1.0
# idx = 23504, chi2cdf = 1.0
# idx = 23505, chi2cdf = 1.0
# idx = 23506, chi2cdf = 1.0
# idx = 23507, chi2cdf = 1.0
# idx = 23508, chi2cdf = 1.0
# idx = 23509, chi2cdf = 1.0
# idx = 23510, chi2cdf = 1.0
# idx = 23511, chi2cdf = 1.0
# idx = 23512, chi2cdf = 1.0
# idx = 23513, chi2cdf = 1.0
# idx = 23514, chi2cdf = 1.0
# idx = 23515, chi2cdf = 1.0
# idx = 23516, chi2cdf = 1.0
# idx = 23517, chi2cdf = 1.0
# idx = 23518, chi2cdf = 1.0
# idx = 23519, chi2cdf = 1.0
# idx = 23520, chi2cdf = 1.0
# idx = 23521, chi2cdf = 1.0
# idx = 23522, chi2cdf = 1.0
# idx = 23523, chi2cdf = 1.0
# idx = 23524, chi2cdf = 1.0
# idx = 23525, chi2cdf = 1.0
# idx = 23526, chi2cdf = 1.0
# idx = 23527, chi2cdf = 1.0
# idx = 23528, chi2cdf = 1.0
# idx = 23529, chi2cdf = 1.0
# idx = 23530, chi2cdf = 1.0
# idx = 23531, chi2cdf = 1.0
# idx = 23532, chi2cdf = 1.0
# idx = 23533, chi2cdf = 1.0
# idx = 23534, chi2cdf = 1.0
# idx = 23535, chi2cdf = 1.0
# idx = 23536, chi2cdf = 1.0
# idx = 23537, chi2cdf = 1.0
# idx = 23538, chi2cdf = 1.0
# idx = 23539, chi2cdf = 1.0
# idx = 23540, chi2cdf = 1.0
# idx = 23541, chi2cdf = 1.0
# idx = 23542, chi2cdf = 1.0
# idx = 23543, chi2cdf = 1.0
# idx = 23544, chi2cdf = 1.0
# idx = 23545, chi2cdf = 1.0
# idx = 23546, chi2cdf = 1.0
# idx = 23547, chi2cdf = 1.0
# idx = 23548, chi2cdf = 1.0
# idx = 23549, chi2cdf = 1.0
# idx = 23550, chi2cdf = 1.0
# idx = 23551, chi2cdf = 1.0
# idx = 23552, chi2cdf = 1.0
# idx = 23553, chi2cdf = 1.0
# idx = 23554, chi2cdf = 1.0
# idx = 23555, chi2cdf = 1.0
# idx = 23557, chi2cdf = 1.0
# idx = 23558, chi2cdf = 1.0
# idx = 23559, chi2cdf = 1.0
# idx = 23560, chi2cdf = 1.0
# idx = 23561, chi2cdf = 1.0
# idx = 23563, chi2cdf = 1.0
# idx = 23564, chi2cdf = 1.0
# idx = 23565, chi2cdf = 1.0
# idx = 23566, chi2cdf = 1.0
# idx = 23567, chi2cdf = 1.0
# idx = 23569, chi2cdf = 1.0
# idx = 23570, chi2cdf = 1.0
# idx = 23571, chi2cdf = 1.0
# idx = 23572, chi2cdf = 1.0
# idx = 23573, chi2cdf = 1.0
# idx = 23575, chi2cdf = 1.0
# idx = 23576, chi2cdf = 1.0
# idx = 23577, chi2cdf = 1.0
# idx = 23578, chi2cdf = 1.0
# idx = 23579, chi2cdf = 1.0
# idx = 23580, chi2cdf = 1.0
# idx = 23581, chi2cdf = 1.0
# idx = 23582, chi2cdf = 1.0
# idx = 23583, chi2cdf = 1.0
# idx = 23584, chi2cdf = 1.0
# idx = 23585, chi2cdf = 1.0
# idx = 23586, chi2cdf = 1.0
# idx = 23587, chi2cdf = 1.0
# idx = 23588, chi2cdf = 1.0
# idx = 23589, chi2cdf = 1.0
# idx = 23590, chi2cdf = 1.0
# idx = 23591, chi2cdf = 1.0
# idx = 23592, chi2cdf = 1.0
# idx = 23593, chi2cdf = 1.0
# idx = 23594, chi2cdf = 1.0
# idx = 23595, chi2cdf = 1.0
# idx = 23596, chi2cdf = 1.0
# idx = 23597, chi2cdf = 1.0
# idx = 23598, chi2cdf = 1.0
# idx = 23599, chi2cdf = 1.0
# idx = 23600, chi2cdf = 1.0
# idx = 23601, chi2cdf = 1.0
# idx = 23602, chi2cdf = 1.0
# idx = 23603, chi2cdf = 1.0
# idx = 23604, chi2cdf = 1.0
# idx = 23605, chi2cdf = 1.0
# idx = 23606, chi2cdf = 1.0
# idx = 23607, chi2cdf = 1.0
# idx = 23608, chi2cdf = 1.0
# idx = 23609, chi2cdf = 1.0
# idx = 23626, chi2cdf = 1.0
# idx = 23627, chi2cdf = 1.0
# idx = 23628, chi2cdf = 1.0
# idx = 23629, chi2cdf = 1.0
# idx = 23630, chi2cdf = 1.0
# idx = 23631, chi2cdf = 1.0
# idx = 23632, chi2cdf = 1.0
# idx = 23633, chi2cdf = 1.0
# idx = 23634, chi2cdf = 1.0
# idx = 23635, chi2cdf = 1.0
# idx = 23636, chi2cdf = 1.0
# idx = 23637, chi2cdf = 1.0
# idx = 23638, chi2cdf = 1.0
# idx = 23639, chi2cdf = 1.0
# idx = 23640, chi2cdf = 1.0
# idx = 23641, chi2cdf = 1.0
# idx = 23642, chi2cdf = 1.0
# idx = 23643, chi2cdf = 1.0
# idx = 23644, chi2cdf = 1.0
# idx = 23645, chi2cdf = 1.0
# idx = 23646, chi2cdf = 1.0
# idx = 23647, chi2cdf = 1.0
# idx = 23648, chi2cdf = 1.0
# idx = 23649, chi2cdf = 1.0
# idx = 23650, chi2cdf = 1.0
# idx = 23651, chi2cdf = 1.0
# idx = 23652, chi2cdf = 1.0
# idx = 23653, chi2cdf = 1.0
# idx = 23654, chi2cdf = 1.0
# idx = 23655, chi2cdf = 1.0
# idx = 23656, chi2cdf = 1.0
# idx = 23657, chi2cdf = 1.0
# idx = 23658, chi2cdf = 1.0
# idx = 23659, chi2cdf = 1.0
# idx = 23660, chi2cdf = 1.0
# idx = 23661, chi2cdf = 1.0
# idx = 23662, chi2cdf = 1.0
# idx = 23663, chi2cdf = 1.0
# idx = 23664, chi2cdf = 1.0
# idx = 23665, chi2cdf = 1.0
# idx = 23666, chi2cdf = 1.0
# idx = 23667, chi2cdf = 1.0
# idx = 23668, chi2cdf = 1.0
# idx = 23669, chi2cdf = 1.0
# idx = 23670, chi2cdf = 1.0
# idx = 23671, chi2cdf = 1.0
# idx = 23672, chi2cdf = 1.0
# idx = 23673, chi2cdf = 1.0
# idx = 23674, chi2cdf = 1.0
# idx = 23675, chi2cdf = 1.0
# idx = 23676, chi2cdf = 1.0
# idx = 23677, chi2cdf = 1.0
# idx = 23678, chi2cdf = 1.0
# idx = 23679, chi2cdf = 1.0
# idx = 23680, chi2cdf = 1.0
# idx = 23681, chi2cdf = 1.0
# idx = 23682, chi2cdf = 1.0
# idx = 23683, chi2cdf = 1.0
# idx = 23684, chi2cdf = 1.0
# idx = 23685, chi2cdf = 1.0
# idx = 23686, chi2cdf = 1.0
# idx = 23687, chi2cdf = 1.0
# idx = 23688, chi2cdf = 1.0
# idx = 23689, chi2cdf = 1.0
# idx = 23690, chi2cdf = 1.0
# idx = 23691, chi2cdf = 1.0
# idx = 23692, chi2cdf = 1.0
# idx = 23693, chi2cdf = 1.0
# idx = 23694, chi2cdf = 1.0
# idx = 23695, chi2cdf = 1.0
# idx = 23696, chi2cdf = 1.0
# idx = 23697, chi2cdf = 1.0
# idx = 23698, chi2cdf = 1.0
# idx = 23699, chi2cdf = 1.0
# idx = 23704, chi2cdf = 1.0
# idx = 23705, chi2cdf = 1.0
# idx = 23706, chi2cdf = 1.0
# idx = 23707, chi2cdf = 1.0
# idx = 23708, chi2cdf = 1.0
# idx = 23709, chi2cdf = 1.0
# idx = 23710, chi2cdf = 1.0
# idx = 23711, chi2cdf = 1.0
# idx = 23712, chi2cdf = 1.0
# idx = 23713, chi2cdf = 1.0
# idx = 23714, chi2cdf = 1.0
# idx = 23715, chi2cdf = 1.0
# idx = 23716, chi2cdf = 1.0
# idx = 23717, chi2cdf = 1.0
# idx = 23718, chi2cdf = 1.0
# idx = 23719, chi2cdf = 1.0
# idx = 23720, chi2cdf = 1.0
# idx = 23721, chi2cdf = 1.0
# idx = 23722, chi2cdf = 1.0
# idx = 23723, chi2cdf = 1.0
# idx = 23724, chi2cdf = 1.0
# idx = 23725, chi2cdf = 1.0
# idx = 23726, chi2cdf = 1.0
# idx = 23727, chi2cdf = 1.0
# idx = 23728, chi2cdf = 1.0
# idx = 23729, chi2cdf = 1.0
# idx = 23730, chi2cdf = 1.0
# idx = 23731, chi2cdf = 1.0
# idx = 23732, chi2cdf = 1.0
# idx = 23733, chi2cdf = 1.0
# idx = 23734, chi2cdf = 1.0
# idx = 23735, chi2cdf = 1.0
# idx = 23736, chi2cdf = 1.0
# idx = 23737, chi2cdf = 1.0
# idx = 23738, chi2cdf = 1.0
# idx = 23739, chi2cdf = 1.0
# idx = 23740, chi2cdf = 1.0
# idx = 23741, chi2cdf = 1.0
# idx = 23742, chi2cdf = 1.0
# idx = 23743, chi2cdf = 1.0
# idx = 23744, chi2cdf = 1.0
# idx = 23745, chi2cdf = 1.0
# idx = 23746, chi2cdf = 1.0
# idx = 23747, chi2cdf = 1.0
# idx = 23748, chi2cdf = 1.0
# idx = 23749, chi2cdf = 1.0
# idx = 23750, chi2cdf = 1.0
# idx = 23751, chi2cdf = 1.0
# idx = 23752, chi2cdf = 1.0
# idx = 23753, chi2cdf = 1.0
# idx = 23758, chi2cdf = 1.0
# idx = 23764, chi2cdf = 1.0
# idx = 23770, chi2cdf = 1.0
# idx = 23776, chi2cdf = 1.0
# idx = 23778, chi2cdf = 1.0
# idx = 23779, chi2cdf = 1.0
# idx = 23780, chi2cdf = 1.0
# idx = 23781, chi2cdf = 1.0
# idx = 23782, chi2cdf = 1.0
# idx = 23783, chi2cdf = 1.0
# idx = 23784, chi2cdf = 1.0
# idx = 23785, chi2cdf = 1.0
# idx = 23786, chi2cdf = 1.0
# idx = 23787, chi2cdf = 1.0
# idx = 23788, chi2cdf = 1.0
# idx = 23789, chi2cdf = 1.0
# idx = 23790, chi2cdf = 1.0
# idx = 23791, chi2cdf = 1.0
# idx = 23792, chi2cdf = 1.0
# idx = 23793, chi2cdf = 1.0
# idx = 23794, chi2cdf = 1.0
# idx = 23795, chi2cdf = 1.0
# idx = 23796, chi2cdf = 1.0
# idx = 23797, chi2cdf = 1.0
# idx = 23798, chi2cdf = 1.0
# idx = 23799, chi2cdf = 1.0
# idx = 23800, chi2cdf = 1.0
# idx = 23801, chi2cdf = 1.0
# idx = 23802, chi2cdf = 1.0
# idx = 23803, chi2cdf = 1.0
# idx = 23804, chi2cdf = 1.0
# idx = 23805, chi2cdf = 1.0
# idx = 23806, chi2cdf = 1.0
# idx = 23807, chi2cdf = 1.0
# idx = 23808, chi2cdf = 1.0
# idx = 23809, chi2cdf = 1.0
# idx = 23810, chi2cdf = 1.0
# idx = 23811, chi2cdf = 1.0
# idx = 23812, chi2cdf = 1.0
# idx = 23813, chi2cdf = 1.0
# idx = 23814, chi2cdf = 1.0
# idx = 23815, chi2cdf = 1.0
# idx = 23816, chi2cdf = 1.0
# idx = 23817, chi2cdf = 1.0
# idx = 23818, chi2cdf = 1.0
# idx = 23819, chi2cdf = 1.0
# idx = 23820, chi2cdf = 1.0
# idx = 23821, chi2cdf = 1.0
# idx = 23822, chi2cdf = 1.0
# idx = 23823, chi2cdf = 1.0
# idx = 23824, chi2cdf = 1.0
# idx = 23825, chi2cdf = 1.0
# idx = 23826, chi2cdf = 1.0
# idx = 23827, chi2cdf = 1.0
# idx = 23828, chi2cdf = 1.0
# idx = 23829, chi2cdf = 1.0
# idx = 23830, chi2cdf = 1.0
# idx = 23831, chi2cdf = 1.0
# idx = 23832, chi2cdf = 1.0
# idx = 23833, chi2cdf = 1.0
# idx = 23834, chi2cdf = 1.0
# idx = 23835, chi2cdf = 1.0
# idx = 23836, chi2cdf = 1.0
# idx = 23837, chi2cdf = 1.0
# idx = 23838, chi2cdf = 1.0
# idx = 23839, chi2cdf = 1.0
# idx = 23840, chi2cdf = 1.0
# idx = 23841, chi2cdf = 1.0
# idx = 23842, chi2cdf = 1.0
# idx = 23843, chi2cdf = 1.0
# idx = 23844, chi2cdf = 1.0
# idx = 23845, chi2cdf = 1.0
# idx = 23846, chi2cdf = 1.0
# idx = 23847, chi2cdf = 1.0
# idx = 23848, chi2cdf = 1.0
# idx = 23849, chi2cdf = 1.0
# idx = 23850, chi2cdf = 1.0
# idx = 23851, chi2cdf = 1.0
# idx = 23852, chi2cdf = 1.0
# idx = 23853, chi2cdf = 1.0
# idx = 23854, chi2cdf = 1.0
# idx = 23855, chi2cdf = 1.0
# idx = 23856, chi2cdf = 1.0
# idx = 23857, chi2cdf = 1.0
# idx = 23858, chi2cdf = 1.0
# idx = 23859, chi2cdf = 1.0
# idx = 23860, chi2cdf = 1.0
# idx = 23861, chi2cdf = 1.0
# idx = 23866, chi2cdf = 1.0
# idx = 23867, chi2cdf = 1.0
# idx = 23868, chi2cdf = 1.0
# idx = 23869, chi2cdf = 1.0
# idx = 23870, chi2cdf = 1.0
# idx = 23871, chi2cdf = 1.0
# idx = 23872, chi2cdf = 1.0
# idx = 23873, chi2cdf = 1.0
# idx = 23874, chi2cdf = 1.0
# idx = 23875, chi2cdf = 1.0
# idx = 23876, chi2cdf = 1.0
# idx = 23877, chi2cdf = 1.0
# idx = 23878, chi2cdf = 1.0
# idx = 23879, chi2cdf = 1.0
# idx = 23880, chi2cdf = 1.0
# idx = 23881, chi2cdf = 1.0
# idx = 23882, chi2cdf = 1.0
# idx = 23883, chi2cdf = 1.0
# idx = 23884, chi2cdf = 1.0
# idx = 23885, chi2cdf = 1.0
# idx = 23886, chi2cdf = 1.0
# idx = 23887, chi2cdf = 1.0
# idx = 23888, chi2cdf = 1.0
# idx = 23889, chi2cdf = 1.0
# idx = 23890, chi2cdf = 1.0
# idx = 23891, chi2cdf = 1.0
# idx = 23892, chi2cdf = 1.0
# idx = 23893, chi2cdf = 1.0
# idx = 23894, chi2cdf = 1.0
# idx = 23895, chi2cdf = 1.0
# idx = 23896, chi2cdf = 1.0
# idx = 23897, chi2cdf = 1.0
# idx = 23898, chi2cdf = 1.0
# idx = 23899, chi2cdf = 1.0
# idx = 23900, chi2cdf = 1.0
# idx = 23901, chi2cdf = 1.0
# idx = 23902, chi2cdf = 1.0
# idx = 23903, chi2cdf = 1.0
# idx = 23904, chi2cdf = 1.0
# idx = 23905, chi2cdf = 1.0
# idx = 23906, chi2cdf = 1.0
# idx = 23907, chi2cdf = 1.0
# idx = 23908, chi2cdf = 1.0
# idx = 23909, chi2cdf = 1.0
# idx = 23910, chi2cdf = 1.0
# idx = 23911, chi2cdf = 1.0
# idx = 23912, chi2cdf = 1.0
# idx = 23913, chi2cdf = 1.0
# idx = 23914, chi2cdf = 1.0
# idx = 23915, chi2cdf = 1.0
# idx = 23916, chi2cdf = 1.0
# idx = 23917, chi2cdf = 1.0
# idx = 23918, chi2cdf = 1.0
# idx = 23919, chi2cdf = 1.0
# idx = 23920, chi2cdf = 1.0
# idx = 23921, chi2cdf = 1.0
# idx = 23922, chi2cdf = 1.0
# idx = 23923, chi2cdf = 1.0
# idx = 23924, chi2cdf = 1.0
# idx = 23927, chi2cdf = 1.0
# idx = 23928, chi2cdf = 1.0
# idx = 23931, chi2cdf = 1.0
# idx = 23932, chi2cdf = 1.0
# idx = 23935, chi2cdf = 1.0
# idx = 23936, chi2cdf = 1.0
# idx = 23939, chi2cdf = 1.0
# idx = 23940, chi2cdf = 1.0
# idx = 23941, chi2cdf = 1.0
# idx = 23942, chi2cdf = 1.0
# idx = 23943, chi2cdf = 1.0
# idx = 23944, chi2cdf = 1.0
# idx = 23945, chi2cdf = 1.0
# idx = 23946, chi2cdf = 1.0
# idx = 23947, chi2cdf = 1.0
# idx = 23948, chi2cdf = 1.0
# idx = 23949, chi2cdf = 1.0
# idx = 23950, chi2cdf = 1.0
# idx = 23951, chi2cdf = 1.0
# idx = 23952, chi2cdf = 1.0
# idx = 23953, chi2cdf = 1.0
# idx = 23954, chi2cdf = 1.0
# idx = 23955, chi2cdf = 1.0
# idx = 23956, chi2cdf = 1.0
# idx = 23957, chi2cdf = 1.0
# idx = 23958, chi2cdf = 1.0
# idx = 23959, chi2cdf = 1.0
# idx = 23960, chi2cdf = 1.0
# idx = 23961, chi2cdf = 1.0
# idx = 23962, chi2cdf = 1.0
# idx = 23963, chi2cdf = 1.0
# idx = 23964, chi2cdf = 1.0
# idx = 23965, chi2cdf = 1.0
# idx = 23974, chi2cdf = 1.0
# idx = 23975, chi2cdf = 1.0
# idx = 23976, chi2cdf = 1.0
# idx = 23977, chi2cdf = 1.0
# idx = 23978, chi2cdf = 1.0
# idx = 23979, chi2cdf = 1.0
# idx = 23980, chi2cdf = 1.0
# idx = 23981, chi2cdf = 1.0
# idx = 23982, chi2cdf = 1.0
# idx = 23983, chi2cdf = 1.0
# idx = 23984, chi2cdf = 1.0
# idx = 23985, chi2cdf = 1.0
# idx = 23986, chi2cdf = 1.0
# idx = 23987, chi2cdf = 1.0
# idx = 23988, chi2cdf = 1.0
# idx = 23989, chi2cdf = 1.0
# idx = 23990, chi2cdf = 1.0
# idx = 23991, chi2cdf = 1.0
# idx = 23992, chi2cdf = 1.0
# idx = 23993, chi2cdf = 1.0
# idx = 23994, chi2cdf = 1.0
# idx = 23995, chi2cdf = 1.0
# idx = 23996, chi2cdf = 1.0
# idx = 23997, chi2cdf = 1.0
# idx = 23998, chi2cdf = 1.0
# idx = 23999, chi2cdf = 1.0
# idx = 24000, chi2cdf = 1.0
# idx = 24001, chi2cdf = 1.0
# idx = 24002, chi2cdf = 1.0
# idx = 24003, chi2cdf = 1.0
# idx = 24004, chi2cdf = 1.0
# idx = 24005, chi2cdf = 1.0
# idx = 24006, chi2cdf = 1.0
# idx = 24007, chi2cdf = 1.0
# idx = 24008, chi2cdf = 1.0
# idx = 24009, chi2cdf = 1.0
# idx = 24010, chi2cdf = 1.0
# idx = 24011, chi2cdf = 1.0
# idx = 24012, chi2cdf = 1.0
# idx = 24013, chi2cdf = 1.0
# idx = 24014, chi2cdf = 1.0
# idx = 24015, chi2cdf = 1.0
# idx = 24016, chi2cdf = 1.0
# idx = 24017, chi2cdf = 1.0
# idx = 24018, chi2cdf = 1.0
# idx = 24019, chi2cdf = 1.0
# idx = 24020, chi2cdf = 1.0
# idx = 24021, chi2cdf = 1.0
# idx = 24022, chi2cdf = 1.0
# idx = 24023, chi2cdf = 1.0
# idx = 24024, chi2cdf = 1.0
# idx = 24025, chi2cdf = 1.0
# idx = 24026, chi2cdf = 1.0
# idx = 24027, chi2cdf = 1.0
# idx = 24028, chi2cdf = 1.0
# idx = 24029, chi2cdf = 1.0
# idx = 24030, chi2cdf = 1.0
# idx = 24031, chi2cdf = 1.0
# idx = 24032, chi2cdf = 1.0
# idx = 24033, chi2cdf = 1.0
# idx = 24034, chi2cdf = 1.0
# idx = 24035, chi2cdf = 1.0
# idx = 24036, chi2cdf = 1.0
# idx = 24037, chi2cdf = 1.0
# idx = 24038, chi2cdf = 1.0
# idx = 24039, chi2cdf = 1.0
# idx = 24040, chi2cdf = 1.0
# idx = 24041, chi2cdf = 1.0
# idx = 24042, chi2cdf = 1.0
# idx = 24043, chi2cdf = 1.0
# idx = 24044, chi2cdf = 1.0
# idx = 24045, chi2cdf = 1.0
# idx = 24046, chi2cdf = 1.0
# idx = 24047, chi2cdf = 1.0
# idx = 24048, chi2cdf = 1.0
# idx = 24049, chi2cdf = 1.0
# idx = 24050, chi2cdf = 1.0
# idx = 24051, chi2cdf = 1.0
# idx = 24052, chi2cdf = 1.0
# idx = 24053, chi2cdf = 1.0
# idx = 24054, chi2cdf = 1.0
# idx = 24055, chi2cdf = 1.0
# idx = 24056, chi2cdf = 1.0
# idx = 24057, chi2cdf = 1.0
# idx = 24058, chi2cdf = 1.0
# idx = 24059, chi2cdf = 1.0
# idx = 24060, chi2cdf = 1.0
# idx = 24061, chi2cdf = 1.0
# idx = 24062, chi2cdf = 1.0
# idx = 24063, chi2cdf = 1.0
# idx = 24064, chi2cdf = 1.0
# idx = 24065, chi2cdf = 1.0
# idx = 24066, chi2cdf = 1.0
# idx = 24067, chi2cdf = 1.0
# idx = 24068, chi2cdf = 1.0
# idx = 24069, chi2cdf = 1.0
# idx = 24070, chi2cdf = 1.0
# idx = 24071, chi2cdf = 1.0
# idx = 24072, chi2cdf = 1.0
# idx = 24073, chi2cdf = 1.0
# idx = 24074, chi2cdf = 1.0
# idx = 24075, chi2cdf = 1.0
# idx = 24076, chi2cdf = 1.0
# idx = 24077, chi2cdf = 1.0
# idx = 24078, chi2cdf = 1.0
# idx = 24079, chi2cdf = 1.0
# idx = 24080, chi2cdf = 1.0
# idx = 24081, chi2cdf = 1.0
# idx = 24082, chi2cdf = 1.0
# idx = 24083, chi2cdf = 1.0
# idx = 24084, chi2cdf = 1.0
# idx = 24085, chi2cdf = 1.0
# idx = 24086, chi2cdf = 1.0
# idx = 24087, chi2cdf = 1.0
# idx = 24088, chi2cdf = 1.0
# idx = 24089, chi2cdf = 1.0
# idx = 24090, chi2cdf = 1.0
# idx = 24091, chi2cdf = 1.0
# idx = 24092, chi2cdf = 1.0
# idx = 24093, chi2cdf = 1.0
# idx = 24094, chi2cdf = 1.0
# idx = 24095, chi2cdf = 1.0
# idx = 24096, chi2cdf = 1.0
# idx = 24097, chi2cdf = 1.0
# idx = 24098, chi2cdf = 1.0
# idx = 24099, chi2cdf = 1.0
# idx = 24100, chi2cdf = 1.0
# idx = 24101, chi2cdf = 1.0
# idx = 24102, chi2cdf = 1.0
# idx = 24103, chi2cdf = 1.0
# idx = 24104, chi2cdf = 1.0
# idx = 24105, chi2cdf = 1.0
# idx = 24106, chi2cdf = 1.0
# idx = 24107, chi2cdf = 1.0
# idx = 24108, chi2cdf = 1.0
# idx = 24109, chi2cdf = 1.0
# idx = 24110, chi2cdf = 1.0
# idx = 24111, chi2cdf = 1.0
# idx = 24112, chi2cdf = 1.0
# idx = 24113, chi2cdf = 1.0
# idx = 24114, chi2cdf = 1.0
# idx = 24115, chi2cdf = 1.0
# idx = 24116, chi2cdf = 1.0
# idx = 24117, chi2cdf = 1.0
# idx = 24118, chi2cdf = 1.0
# idx = 24119, chi2cdf = 1.0
# idx = 24120, chi2cdf = 1.0
# idx = 24122, chi2cdf = 1.0
# idx = 24138, chi2cdf = 1.0
# idx = 24139, chi2cdf = 1.0
# idx = 24140, chi2cdf = 1.0
# idx = 24141, chi2cdf = 1.0
# idx = 24143, chi2cdf = 1.0
# idx = 24144, chi2cdf = 1.0
# idx = 24145, chi2cdf = 1.0
# idx = 24146, chi2cdf = 1.0
# idx = 24147, chi2cdf = 1.0
# idx = 24148, chi2cdf = 1.0
# idx = 24150, chi2cdf = 1.0
# idx = 24151, chi2cdf = 1.0
# idx = 24152, chi2cdf = 1.0
# idx = 24153, chi2cdf = 1.0
# idx = 24154, chi2cdf = 1.0
# idx = 24156, chi2cdf = 1.0
# idx = 24157, chi2cdf = 1.0
# idx = 24158, chi2cdf = 1.0
# idx = 24159, chi2cdf = 1.0
# idx = 24160, chi2cdf = 1.0
# idx = 24161, chi2cdf = 1.0
# idx = 24162, chi2cdf = 1.0
# idx = 24164, chi2cdf = 1.0
# idx = 24165, chi2cdf = 1.0
# idx = 24166, chi2cdf = 1.0
# idx = 24167, chi2cdf = 1.0
# idx = 24168, chi2cdf = 1.0
# idx = 24169, chi2cdf = 1.0
# idx = 24170, chi2cdf = 1.0
# idx = 24171, chi2cdf = 1.0
# idx = 24172, chi2cdf = 1.0
# idx = 24173, chi2cdf = 1.0
# idx = 24174, chi2cdf = 1.0
# idx = 24175, chi2cdf = 1.0
# idx = 24176, chi2cdf = 1.0
# idx = 24177, chi2cdf = 1.0
# idx = 24178, chi2cdf = 1.0
# idx = 24179, chi2cdf = 1.0
# idx = 24180, chi2cdf = 1.0
# idx = 24181, chi2cdf = 1.0
# idx = 24182, chi2cdf = 1.0
# idx = 24183, chi2cdf = 1.0
# idx = 24184, chi2cdf = 1.0
# idx = 24185, chi2cdf = 1.0
# idx = 24186, chi2cdf = 1.0
# idx = 24187, chi2cdf = 1.0
# idx = 24188, chi2cdf = 1.0
# idx = 24189, chi2cdf = 1.0
# idx = 24190, chi2cdf = 1.0
# idx = 24191, chi2cdf = 1.0
# idx = 24192, chi2cdf = 1.0
# idx = 24193, chi2cdf = 1.0
# idx = 24194, chi2cdf = 1.0
# idx = 24195, chi2cdf = 1.0
# idx = 24196, chi2cdf = 1.0
# idx = 24197, chi2cdf = 1.0
# idx = 24198, chi2cdf = 1.0
# idx = 24199, chi2cdf = 1.0
# idx = 24200, chi2cdf = 1.0
# idx = 24201, chi2cdf = 1.0
# idx = 24202, chi2cdf = 1.0
# idx = 24203, chi2cdf = 1.0
# idx = 24204, chi2cdf = 1.0
# idx = 24205, chi2cdf = 1.0
# idx = 24206, chi2cdf = 1.0
# idx = 24207, chi2cdf = 1.0
# idx = 24208, chi2cdf = 1.0
# idx = 24209, chi2cdf = 1.0
# idx = 24210, chi2cdf = 1.0
# idx = 24211, chi2cdf = 1.0
# idx = 24212, chi2cdf = 1.0
# idx = 24213, chi2cdf = 1.0
# idx = 24214, chi2cdf = 1.0
# idx = 24215, chi2cdf = 1.0
# idx = 24216, chi2cdf = 1.0
# idx = 24217, chi2cdf = 1.0
# idx = 24218, chi2cdf = 1.0
# idx = 24219, chi2cdf = 1.0
# idx = 24220, chi2cdf = 1.0
# idx = 24221, chi2cdf = 1.0
# idx = 24222, chi2cdf = 1.0
# idx = 24223, chi2cdf = 1.0
# idx = 24224, chi2cdf = 1.0
# idx = 24225, chi2cdf = 1.0
# idx = 24226, chi2cdf = 1.0
# idx = 24227, chi2cdf = 1.0
# idx = 24228, chi2cdf = 1.0
# idx = 24229, chi2cdf = 1.0
# idx = 24230, chi2cdf = 1.0
# idx = 24231, chi2cdf = 1.0
# idx = 24232, chi2cdf = 1.0
# idx = 24233, chi2cdf = 1.0
# idx = 24234, chi2cdf = 1.0
# idx = 24235, chi2cdf = 1.0
# idx = 24236, chi2cdf = 1.0
# idx = 24237, chi2cdf = 1.0
# idx = 24238, chi2cdf = 1.0
# idx = 24239, chi2cdf = 1.0
# idx = 24240, chi2cdf = 1.0
# idx = 24241, chi2cdf = 1.0
# idx = 24242, chi2cdf = 1.0
# idx = 24243, chi2cdf = 1.0
# idx = 24244, chi2cdf = 1.0
# idx = 24245, chi2cdf = 1.0
# idx = 24246, chi2cdf = 1.0
# idx = 24247, chi2cdf = 1.0
# idx = 24248, chi2cdf = 1.0
# idx = 24249, chi2cdf = 1.0
# idx = 24250, chi2cdf = 1.0
# idx = 24251, chi2cdf = 1.0
# idx = 24252, chi2cdf = 1.0
# idx = 24253, chi2cdf = 1.0
# idx = 24254, chi2cdf = 1.0
# idx = 24255, chi2cdf = 1.0
# idx = 24256, chi2cdf = 1.0
# idx = 24257, chi2cdf = 1.0
# idx = 24258, chi2cdf = 1.0
# idx = 24259, chi2cdf = 1.0
# idx = 24260, chi2cdf = 1.0
# idx = 24261, chi2cdf = 1.0
# idx = 24262, chi2cdf = 1.0
# idx = 24263, chi2cdf = 1.0
# idx = 24264, chi2cdf = 1.0
# idx = 24265, chi2cdf = 1.0
# idx = 24266, chi2cdf = 1.0
# idx = 24267, chi2cdf = 1.0
# idx = 24268, chi2cdf = 1.0
# idx = 24269, chi2cdf = 1.0
# idx = 24270, chi2cdf = 1.0
# idx = 24271, chi2cdf = 1.0
# idx = 24272, chi2cdf = 1.0
# idx = 24273, chi2cdf = 1.0
# idx = 24274, chi2cdf = 1.0
# idx = 24275, chi2cdf = 1.0
# idx = 24276, chi2cdf = 1.0
# idx = 24277, chi2cdf = 1.0
# idx = 24278, chi2cdf = 1.0
# idx = 24279, chi2cdf = 1.0
# idx = 24280, chi2cdf = 1.0
# idx = 24281, chi2cdf = 1.0
# idx = 24282, chi2cdf = 1.0
# idx = 24283, chi2cdf = 1.0
# idx = 24284, chi2cdf = 1.0
# idx = 24285, chi2cdf = 1.0
# idx = 24286, chi2cdf = 1.0
# idx = 24287, chi2cdf = 1.0
# idx = 24288, chi2cdf = 1.0
# idx = 24289, chi2cdf = 1.0
# idx = 24290, chi2cdf = 1.0
# idx = 24291, chi2cdf = 1.0
# idx = 24292, chi2cdf = 1.0
# idx = 24293, chi2cdf = 1.0
# idx = 24294, chi2cdf = 1.0
# idx = 24295, chi2cdf = 1.0
# idx = 24296, chi2cdf = 1.0
# idx = 24297, chi2cdf = 1.0
# idx = 24298, chi2cdf = 1.0
# idx = 24301, chi2cdf = 1.0
# idx = 24303, chi2cdf = 1.0
# idx = 24307, chi2cdf = 1.0
# idx = 24310, chi2cdf = 1.0
# idx = 24311, chi2cdf = 1.0
# idx = 24312, chi2cdf = 1.0
# idx = 24313, chi2cdf = 1.0
# idx = 24315, chi2cdf = 1.0
# idx = 24316, chi2cdf = 1.0
# idx = 24317, chi2cdf = 1.0
# idx = 24318, chi2cdf = 1.0
# idx = 24319, chi2cdf = 1.0
# idx = 24321, chi2cdf = 1.0
# idx = 24322, chi2cdf = 1.0
# idx = 24323, chi2cdf = 1.0
# idx = 24324, chi2cdf = 1.0
# idx = 24326, chi2cdf = 1.0
# idx = 24327, chi2cdf = 1.0
# idx = 24328, chi2cdf = 1.0
# idx = 24329, chi2cdf = 1.0
# idx = 24330, chi2cdf = 1.0
# idx = 24332, chi2cdf = 1.0
# idx = 24333, chi2cdf = 1.0
# idx = 24334, chi2cdf = 1.0
# idx = 24335, chi2cdf = 1.0
# idx = 24336, chi2cdf = 1.0
# idx = 24337, chi2cdf = 1.0
# idx = 24338, chi2cdf = 1.0
# idx = 24339, chi2cdf = 1.0
# idx = 24340, chi2cdf = 1.0
# idx = 24341, chi2cdf = 1.0
# idx = 24342, chi2cdf = 1.0
# idx = 24343, chi2cdf = 1.0
# idx = 24344, chi2cdf = 1.0
# idx = 24345, chi2cdf = 1.0
# idx = 24346, chi2cdf = 1.0
# idx = 24347, chi2cdf = 1.0
# idx = 24348, chi2cdf = 1.0
# idx = 24349, chi2cdf = 1.0
# idx = 24350, chi2cdf = 1.0
# idx = 24351, chi2cdf = 1.0
# idx = 24352, chi2cdf = 1.0
# idx = 24353, chi2cdf = 1.0
# idx = 24354, chi2cdf = 1.0
# idx = 24355, chi2cdf = 1.0
# idx = 24356, chi2cdf = 1.0
# idx = 24357, chi2cdf = 1.0
# idx = 24358, chi2cdf = 1.0
# idx = 24359, chi2cdf = 1.0
# idx = 24360, chi2cdf = 1.0
# idx = 24361, chi2cdf = 1.0
# idx = 24362, chi2cdf = 1.0
# idx = 24363, chi2cdf = 1.0
# idx = 24364, chi2cdf = 1.0
# idx = 24365, chi2cdf = 1.0
# idx = 24366, chi2cdf = 1.0
# idx = 24367, chi2cdf = 1.0
# idx = 24368, chi2cdf = 1.0
# idx = 24369, chi2cdf = 1.0
# idx = 24370, chi2cdf = 1.0
# idx = 24371, chi2cdf = 1.0
# idx = 24372, chi2cdf = 1.0
# idx = 24373, chi2cdf = 1.0
# idx = 24374, chi2cdf = 1.0
# idx = 24375, chi2cdf = 1.0
# idx = 24376, chi2cdf = 1.0
# idx = 24377, chi2cdf = 1.0
# idx = 24378, chi2cdf = 1.0
# idx = 24379, chi2cdf = 1.0
# idx = 24380, chi2cdf = 1.0
# idx = 24381, chi2cdf = 1.0
# idx = 24382, chi2cdf = 1.0
# idx = 24383, chi2cdf = 1.0
# idx = 24384, chi2cdf = 1.0
# idx = 24385, chi2cdf = 1.0
# idx = 24386, chi2cdf = 1.0
# idx = 24387, chi2cdf = 1.0
# idx = 24388, chi2cdf = 1.0
# idx = 24389, chi2cdf = 1.0
# idx = 24390, chi2cdf = 1.0
# idx = 24391, chi2cdf = 1.0
# idx = 24392, chi2cdf = 1.0
# idx = 24393, chi2cdf = 1.0
# idx = 24394, chi2cdf = 1.0
# idx = 24395, chi2cdf = 1.0
# idx = 24396, chi2cdf = 1.0
# idx = 24397, chi2cdf = 1.0
# idx = 24398, chi2cdf = 1.0
# idx = 24399, chi2cdf = 1.0
# idx = 24400, chi2cdf = 1.0
# idx = 24401, chi2cdf = 1.0
# idx = 24402, chi2cdf = 1.0
# idx = 24403, chi2cdf = 1.0
# idx = 24404, chi2cdf = 1.0
# idx = 24405, chi2cdf = 1.0
# idx = 24406, chi2cdf = 1.0
# idx = 24407, chi2cdf = 1.0
# idx = 24408, chi2cdf = 1.0
# idx = 24409, chi2cdf = 1.0
# idx = 24410, chi2cdf = 1.0
# idx = 24411, chi2cdf = 1.0
# idx = 24412, chi2cdf = 1.0
# idx = 24413, chi2cdf = 1.0
# idx = 24414, chi2cdf = 1.0
# idx = 24415, chi2cdf = 1.0
# idx = 24416, chi2cdf = 1.0
# idx = 24417, chi2cdf = 1.0
# idx = 24418, chi2cdf = 1.0
# idx = 24419, chi2cdf = 1.0
# idx = 24420, chi2cdf = 1.0
# idx = 24421, chi2cdf = 1.0
# idx = 24422, chi2cdf = 1.0
# idx = 24423, chi2cdf = 1.0
# idx = 24424, chi2cdf = 1.0
# idx = 24425, chi2cdf = 1.0
# idx = 24427, chi2cdf = 1.0
# idx = 24430, chi2cdf = 1.0
# idx = 24432, chi2cdf = 1.0
# idx = 24433, chi2cdf = 1.0
# idx = 24434, chi2cdf = 1.0
# idx = 24435, chi2cdf = 1.0
# idx = 24436, chi2cdf = 1.0
# idx = 24437, chi2cdf = 1.0
# idx = 24438, chi2cdf = 1.0
# idx = 24439, chi2cdf = 1.0
# idx = 24440, chi2cdf = 1.0
# idx = 24441, chi2cdf = 1.0
# idx = 24442, chi2cdf = 1.0
# idx = 24443, chi2cdf = 1.0
# idx = 24444, chi2cdf = 1.0
# idx = 24445, chi2cdf = 1.0
# idx = 24446, chi2cdf = 1.0
# idx = 24447, chi2cdf = 1.0
# idx = 24448, chi2cdf = 1.0
# idx = 24449, chi2cdf = 1.0
# idx = 24450, chi2cdf = 1.0
# idx = 24451, chi2cdf = 1.0
# idx = 24452, chi2cdf = 1.0
# idx = 24453, chi2cdf = 1.0
# idx = 24454, chi2cdf = 1.0
# idx = 24455, chi2cdf = 1.0
# idx = 24456, chi2cdf = 1.0
# idx = 24457, chi2cdf = 1.0
# idx = 24458, chi2cdf = 1.0
# idx = 24460, chi2cdf = 1.0
# idx = 24461, chi2cdf = 1.0
# idx = 24462, chi2cdf = 1.0
# idx = 24464, chi2cdf = 1.0
# idx = 24466, chi2cdf = 1.0
# idx = 24467, chi2cdf = 1.0
# idx = 24468, chi2cdf = 1.0
# idx = 24470, chi2cdf = 1.0
# idx = 24471, chi2cdf = 1.0
# idx = 24472, chi2cdf = 1.0
# idx = 24473, chi2cdf = 1.0
# idx = 24474, chi2cdf = 1.0
# idx = 24475, chi2cdf = 1.0
# idx = 24476, chi2cdf = 1.0
# idx = 24477, chi2cdf = 1.0
# idx = 24478, chi2cdf = 1.0
# idx = 24479, chi2cdf = 1.0
# idx = 24480, chi2cdf = 1.0
# idx = 24481, chi2cdf = 1.0
# idx = 24482, chi2cdf = 1.0
# idx = 24483, chi2cdf = 1.0
# idx = 24484, chi2cdf = 1.0
# idx = 24485, chi2cdf = 1.0
# idx = 24486, chi2cdf = 1.0
# idx = 24487, chi2cdf = 1.0
# idx = 24488, chi2cdf = 1.0
# idx = 24489, chi2cdf = 1.0
# idx = 24490, chi2cdf = 1.0
# idx = 24491, chi2cdf = 1.0
# idx = 24492, chi2cdf = 1.0
# idx = 24493, chi2cdf = 1.0
# idx = 24494, chi2cdf = 1.0
# idx = 24495, chi2cdf = 1.0
# idx = 24496, chi2cdf = 1.0
# idx = 24497, chi2cdf = 1.0
# idx = 24498, chi2cdf = 1.0
# idx = 24499, chi2cdf = 1.0
# idx = 24500, chi2cdf = 1.0
# idx = 24501, chi2cdf = 1.0
# idx = 24502, chi2cdf = 1.0
# idx = 24503, chi2cdf = 1.0
# idx = 24504, chi2cdf = 1.0
# idx = 24505, chi2cdf = 1.0
# idx = 24506, chi2cdf = 1.0
# idx = 24507, chi2cdf = 1.0
# idx = 24508, chi2cdf = 1.0
# idx = 24509, chi2cdf = 1.0
# idx = 24510, chi2cdf = 1.0
# idx = 24511, chi2cdf = 1.0
# idx = 24512, chi2cdf = 1.0
# idx = 24513, chi2cdf = 1.0
# idx = 24514, chi2cdf = 1.0
# idx = 24515, chi2cdf = 1.0
# idx = 24516, chi2cdf = 1.0
# idx = 24517, chi2cdf = 1.0
# idx = 24518, chi2cdf = 1.0
# idx = 24519, chi2cdf = 1.0
# idx = 24520, chi2cdf = 1.0
# idx = 24521, chi2cdf = 1.0
# idx = 24522, chi2cdf = 1.0
# idx = 24523, chi2cdf = 1.0
# idx = 24524, chi2cdf = 1.0
# idx = 24525, chi2cdf = 1.0
# idx = 24526, chi2cdf = 1.0
# idx = 24527, chi2cdf = 1.0
# idx = 24528, chi2cdf = 1.0
# idx = 24529, chi2cdf = 1.0
# idx = 24530, chi2cdf = 1.0
# idx = 24531, chi2cdf = 1.0
# idx = 24533, chi2cdf = 1.0
# idx = 24534, chi2cdf = 1.0
# idx = 24536, chi2cdf = 1.0
# idx = 24537, chi2cdf = 1.0
# idx = 24539, chi2cdf = 1.0
# idx = 24540, chi2cdf = 1.0
# idx = 24542, chi2cdf = 1.0
# idx = 24543, chi2cdf = 1.0
# idx = 24544, chi2cdf = 1.0
# idx = 24545, chi2cdf = 1.0
# idx = 24546, chi2cdf = 1.0
# idx = 24547, chi2cdf = 1.0
# idx = 24548, chi2cdf = 1.0
# idx = 24549, chi2cdf = 1.0
# idx = 24550, chi2cdf = 1.0
# idx = 24551, chi2cdf = 1.0
# idx = 24552, chi2cdf = 1.0
# idx = 24553, chi2cdf = 1.0
# idx = 24554, chi2cdf = 1.0
# idx = 24555, chi2cdf = 1.0
# idx = 24556, chi2cdf = 1.0
# idx = 24557, chi2cdf = 1.0
# idx = 24558, chi2cdf = 1.0
# idx = 24559, chi2cdf = 1.0
# idx = 24560, chi2cdf = 1.0
# idx = 24561, chi2cdf = 1.0
# idx = 24562, chi2cdf = 1.0
# idx = 24563, chi2cdf = 1.0
# idx = 24564, chi2cdf = 1.0
# idx = 24565, chi2cdf = 1.0
# idx = 24566, chi2cdf = 1.0
# idx = 24567, chi2cdf = 1.0
# idx = 24568, chi2cdf = 1.0
# idx = 24569, chi2cdf = 1.0
# idx = 24570, chi2cdf = 1.0
# idx = 24571, chi2cdf = 1.0
# idx = 24572, chi2cdf = 1.0
# idx = 24573, chi2cdf = 1.0
# idx = 24574, chi2cdf = 1.0
# idx = 24575, chi2cdf = 1.0
# idx = 24576, chi2cdf = 1.0
# idx = 24577, chi2cdf = 1.0
# idx = 24578, chi2cdf = 1.0
# idx = 24579, chi2cdf = 1.0
# idx = 24580, chi2cdf = 1.0
# idx = 24581, chi2cdf = 1.0
# idx = 24582, chi2cdf = 1.0
# idx = 24583, chi2cdf = 1.0
# idx = 24584, chi2cdf = 1.0
# idx = 24585, chi2cdf = 1.0
# idx = 24586, chi2cdf = 1.0
# idx = 24587, chi2cdf = 1.0
# idx = 24588, chi2cdf = 1.0
# idx = 24589, chi2cdf = 1.0
# idx = 24590, chi2cdf = 1.0
# idx = 24591, chi2cdf = 1.0
# idx = 24592, chi2cdf = 1.0
# idx = 24593, chi2cdf = 1.0
# idx = 24594, chi2cdf = 1.0
# idx = 24595, chi2cdf = 1.0
# idx = 24596, chi2cdf = 1.0
# idx = 24597, chi2cdf = 1.0
# idx = 24598, chi2cdf = 1.0
# idx = 24599, chi2cdf = 1.0
# idx = 24600, chi2cdf = 1.0
# idx = 24601, chi2cdf = 1.0
# idx = 24602, chi2cdf = 1.0
# idx = 24603, chi2cdf = 1.0
# idx = 24604, chi2cdf = 1.0
# idx = 24605, chi2cdf = 1.0
# idx = 24606, chi2cdf = 1.0
# idx = 24607, chi2cdf = 1.0
# idx = 24608, chi2cdf = 1.0
# idx = 24609, chi2cdf = 1.0
# idx = 24610, chi2cdf = 1.0
# idx = 24611, chi2cdf = 1.0
# idx = 24612, chi2cdf = 1.0
# idx = 24613, chi2cdf = 1.0
# idx = 24614, chi2cdf = 1.0
# idx = 24615, chi2cdf = 1.0
# idx = 24616, chi2cdf = 1.0
# idx = 24617, chi2cdf = 1.0
# idx = 24618, chi2cdf = 1.0
# idx = 24619, chi2cdf = 1.0
# idx = 24620, chi2cdf = 1.0
# idx = 24621, chi2cdf = 1.0
# idx = 24622, chi2cdf = 1.0
# idx = 24623, chi2cdf = 1.0
# idx = 24624, chi2cdf = 1.0
# idx = 24625, chi2cdf = 1.0
# idx = 24626, chi2cdf = 1.0
# idx = 24627, chi2cdf = 1.0
# idx = 24628, chi2cdf = 1.0
# idx = 24629, chi2cdf = 1.0
# idx = 24630, chi2cdf = 1.0
# idx = 24631, chi2cdf = 1.0
# idx = 24632, chi2cdf = 1.0
# idx = 24633, chi2cdf = 1.0
# idx = 24634, chi2cdf = 1.0
# idx = 24635, chi2cdf = 1.0
# idx = 24636, chi2cdf = 1.0
# idx = 24637, chi2cdf = 1.0
# idx = 24638, chi2cdf = 1.0
# idx = 24639, chi2cdf = 1.0
# idx = 24640, chi2cdf = 1.0
# idx = 24641, chi2cdf = 1.0
# idx = 24642, chi2cdf = 1.0
# idx = 24643, chi2cdf = 1.0
# idx = 24644, chi2cdf = 1.0
# idx = 24645, chi2cdf = 1.0
# idx = 24646, chi2cdf = 1.0
# idx = 24647, chi2cdf = 1.0
# idx = 24648, chi2cdf = 1.0
# idx = 24649, chi2cdf = 1.0
# idx = 24650, chi2cdf = 1.0
# idx = 24651, chi2cdf = 1.0
# idx = 24652, chi2cdf = 1.0
# idx = 24653, chi2cdf = 1.0
# idx = 24654, chi2cdf = 1.0
# idx = 24655, chi2cdf = 1.0
# idx = 24656, chi2cdf = 1.0
# idx = 24657, chi2cdf = 1.0
# idx = 24658, chi2cdf = 1.0
# idx = 24659, chi2cdf = 1.0
# idx = 24660, chi2cdf = 1.0
# idx = 24661, chi2cdf = 1.0
# idx = 24662, chi2cdf = 1.0
# idx = 24663, chi2cdf = 1.0
# idx = 24664, chi2cdf = 1.0
# idx = 24665, chi2cdf = 1.0
# idx = 24666, chi2cdf = 1.0
# idx = 24667, chi2cdf = 1.0
# idx = 24668, chi2cdf = 1.0
# idx = 24669, chi2cdf = 1.0
# idx = 24670, chi2cdf = 1.0
# idx = 24671, chi2cdf = 1.0
# idx = 24672, chi2cdf = 1.0
# idx = 24673, chi2cdf = 1.0
# idx = 24674, chi2cdf = 1.0
# idx = 24675, chi2cdf = 1.0
# idx = 24676, chi2cdf = 1.0
# idx = 24677, chi2cdf = 1.0
# idx = 24678, chi2cdf = 1.0
# idx = 24680, chi2cdf = 1.0
# idx = 24692, chi2cdf = 1.0
# idx = 24693, chi2cdf = 1.0
# idx = 24696, chi2cdf = 1.0
# idx = 24697, chi2cdf = 1.0
# idx = 24698, chi2cdf = 1.0
# idx = 24699, chi2cdf = 1.0
# idx = 24700, chi2cdf = 1.0
# idx = 24701, chi2cdf = 1.0
# idx = 24703, chi2cdf = 1.0
# idx = 24705, chi2cdf = 1.0
# idx = 24706, chi2cdf = 1.0
# idx = 24707, chi2cdf = 1.0
# idx = 24708, chi2cdf = 1.0
# idx = 24711, chi2cdf = 1.0
# idx = 24712, chi2cdf = 1.0
# idx = 24713, chi2cdf = 1.0
# idx = 24714, chi2cdf = 1.0
# idx = 24715, chi2cdf = 1.0
# idx = 24716, chi2cdf = 1.0
# idx = 24717, chi2cdf = 1.0
# idx = 24719, chi2cdf = 1.0
# idx = 24721, chi2cdf = 1.0
# idx = 24722, chi2cdf = 1.0
# idx = 24723, chi2cdf = 1.0
# idx = 24724, chi2cdf = 1.0
# idx = 24725, chi2cdf = 1.0
# idx = 24726, chi2cdf = 1.0
# idx = 24727, chi2cdf = 1.0
# idx = 24728, chi2cdf = 1.0
# idx = 24729, chi2cdf = 1.0
# idx = 24730, chi2cdf = 1.0
# idx = 24731, chi2cdf = 1.0
# idx = 24732, chi2cdf = 1.0
# idx = 24733, chi2cdf = 1.0
# idx = 24734, chi2cdf = 1.0
# idx = 24735, chi2cdf = 1.0
# idx = 24736, chi2cdf = 1.0
# idx = 24737, chi2cdf = 1.0
# idx = 24738, chi2cdf = 1.0
# idx = 24739, chi2cdf = 1.0
# idx = 24740, chi2cdf = 1.0
# idx = 24741, chi2cdf = 1.0
# idx = 24742, chi2cdf = 1.0
# idx = 24743, chi2cdf = 1.0
# idx = 24744, chi2cdf = 1.0
# idx = 24745, chi2cdf = 1.0
# idx = 24746, chi2cdf = 1.0
# idx = 24747, chi2cdf = 1.0
# idx = 24748, chi2cdf = 1.0
# idx = 24749, chi2cdf = 1.0
# idx = 24750, chi2cdf = 1.0
# idx = 24751, chi2cdf = 1.0
# idx = 24752, chi2cdf = 1.0
# idx = 24753, chi2cdf = 1.0
# idx = 24754, chi2cdf = 1.0
# idx = 24755, chi2cdf = 1.0
# idx = 24756, chi2cdf = 1.0
# idx = 24757, chi2cdf = 1.0
# idx = 24758, chi2cdf = 1.0
# idx = 24759, chi2cdf = 1.0
# idx = 24760, chi2cdf = 1.0
# idx = 24761, chi2cdf = 1.0
# idx = 24762, chi2cdf = 1.0
# idx = 24763, chi2cdf = 1.0
# idx = 24764, chi2cdf = 1.0
# idx = 24765, chi2cdf = 1.0
# idx = 24766, chi2cdf = 1.0
# idx = 24767, chi2cdf = 1.0
# idx = 24768, chi2cdf = 1.0
# idx = 24769, chi2cdf = 1.0
# idx = 24770, chi2cdf = 1.0
# idx = 24771, chi2cdf = 1.0
# idx = 24772, chi2cdf = 1.0
# idx = 24773, chi2cdf = 1.0
# idx = 24774, chi2cdf = 1.0
# idx = 24775, chi2cdf = 1.0
# idx = 24776, chi2cdf = 1.0
# idx = 24777, chi2cdf = 1.0
# idx = 24778, chi2cdf = 1.0
# idx = 24779, chi2cdf = 1.0
# idx = 24780, chi2cdf = 1.0
# idx = 24781, chi2cdf = 1.0
# idx = 24782, chi2cdf = 1.0
# idx = 24783, chi2cdf = 1.0
# idx = 24784, chi2cdf = 1.0
# idx = 24785, chi2cdf = 1.0
# idx = 24786, chi2cdf = 1.0
# idx = 24787, chi2cdf = 1.0
# idx = 24788, chi2cdf = 1.0
# idx = 24789, chi2cdf = 1.0
# idx = 24790, chi2cdf = 1.0
# idx = 24791, chi2cdf = 1.0
# idx = 24792, chi2cdf = 1.0
# idx = 24793, chi2cdf = 1.0
# idx = 24794, chi2cdf = 1.0
# idx = 24795, chi2cdf = 1.0
# idx = 24796, chi2cdf = 1.0
# idx = 24797, chi2cdf = 1.0
# idx = 24798, chi2cdf = 1.0
# idx = 24799, chi2cdf = 1.0
# idx = 24800, chi2cdf = 1.0
# idx = 24801, chi2cdf = 1.0
# idx = 24802, chi2cdf = 1.0
# idx = 24803, chi2cdf = 1.0
# idx = 24804, chi2cdf = 1.0
# idx = 24805, chi2cdf = 1.0
# idx = 24806, chi2cdf = 1.0
# idx = 24807, chi2cdf = 1.0
# idx = 24808, chi2cdf = 1.0
# idx = 24809, chi2cdf = 1.0
# idx = 24810, chi2cdf = 1.0
# idx = 24811, chi2cdf = 1.0
# idx = 24812, chi2cdf = 1.0
# idx = 24813, chi2cdf = 1.0
# idx = 24814, chi2cdf = 1.0
# idx = 24815, chi2cdf = 1.0
# idx = 24816, chi2cdf = 1.0
# idx = 24817, chi2cdf = 1.0
# idx = 24818, chi2cdf = 1.0
# idx = 24819, chi2cdf = 1.0
# idx = 24820, chi2cdf = 1.0
# idx = 24821, chi2cdf = 1.0
# idx = 24822, chi2cdf = 1.0
# idx = 24823, chi2cdf = 1.0
# idx = 24824, chi2cdf = 1.0
# idx = 24825, chi2cdf = 1.0
# idx = 24826, chi2cdf = 1.0
# idx = 24827, chi2cdf = 1.0
# idx = 24828, chi2cdf = 1.0
# idx = 24829, chi2cdf = 1.0
# idx = 24830, chi2cdf = 1.0
# idx = 24831, chi2cdf = 1.0
# idx = 24832, chi2cdf = 1.0
# idx = 24833, chi2cdf = 1.0
# idx = 24834, chi2cdf = 1.0
# idx = 24835, chi2cdf = 1.0
# idx = 24838, chi2cdf = 1.0
# idx = 24840, chi2cdf = 1.0
# idx = 24842, chi2cdf = 1.0
# idx = 24845, chi2cdf = 1.0
# idx = 24848, chi2cdf = 1.0
# idx = 24849, chi2cdf = 1.0
# idx = 24850, chi2cdf = 1.0
# idx = 24851, chi2cdf = 1.0
# idx = 24853, chi2cdf = 1.0
# idx = 24854, chi2cdf = 1.0
# idx = 24855, chi2cdf = 1.0
# idx = 24856, chi2cdf = 1.0
# idx = 24857, chi2cdf = 1.0
# idx = 24859, chi2cdf = 1.0
# idx = 24860, chi2cdf = 1.0
# idx = 24861, chi2cdf = 1.0
# idx = 24862, chi2cdf = 1.0
# idx = 24864, chi2cdf = 1.0
# idx = 24865, chi2cdf = 1.0
# idx = 24866, chi2cdf = 1.0
# idx = 24867, chi2cdf = 1.0
# idx = 24868, chi2cdf = 1.0
# idx = 24870, chi2cdf = 1.0
# idx = 24871, chi2cdf = 1.0
# idx = 24872, chi2cdf = 1.0
# idx = 24873, chi2cdf = 1.0
# idx = 24874, chi2cdf = 1.0
# idx = 24875, chi2cdf = 1.0
# idx = 24876, chi2cdf = 1.0
# idx = 24877, chi2cdf = 1.0
# idx = 24878, chi2cdf = 1.0
# idx = 24879, chi2cdf = 1.0
# idx = 24880, chi2cdf = 1.0
# idx = 24881, chi2cdf = 1.0
# idx = 24882, chi2cdf = 1.0
# idx = 24883, chi2cdf = 1.0
# idx = 24884, chi2cdf = 1.0
# idx = 24885, chi2cdf = 1.0
# idx = 24886, chi2cdf = 1.0
# idx = 24887, chi2cdf = 1.0
# idx = 24888, chi2cdf = 1.0
# idx = 24889, chi2cdf = 1.0
# idx = 24890, chi2cdf = 1.0
# idx = 24891, chi2cdf = 1.0
# idx = 24892, chi2cdf = 1.0
# idx = 24893, chi2cdf = 1.0
# idx = 24894, chi2cdf = 1.0
# idx = 24895, chi2cdf = 1.0
# idx = 24896, chi2cdf = 1.0
# idx = 24897, chi2cdf = 1.0
# idx = 24898, chi2cdf = 1.0
# idx = 24899, chi2cdf = 1.0
# idx = 24900, chi2cdf = 1.0
# idx = 24901, chi2cdf = 1.0
# idx = 24902, chi2cdf = 1.0
# idx = 24903, chi2cdf = 1.0
# idx = 24904, chi2cdf = 1.0
# idx = 24905, chi2cdf = 1.0
# idx = 24906, chi2cdf = 1.0
# idx = 24907, chi2cdf = 1.0
# idx = 24908, chi2cdf = 1.0
# idx = 24909, chi2cdf = 1.0
# idx = 24910, chi2cdf = 1.0
# idx = 24911, chi2cdf = 1.0
# idx = 24912, chi2cdf = 1.0
# idx = 24913, chi2cdf = 1.0
# idx = 24914, chi2cdf = 1.0
# idx = 24915, chi2cdf = 1.0
# idx = 24916, chi2cdf = 1.0
# idx = 24917, chi2cdf = 1.0
# idx = 24918, chi2cdf = 1.0
# idx = 24919, chi2cdf = 1.0
# idx = 24920, chi2cdf = 1.0
# idx = 24921, chi2cdf = 1.0
# idx = 24922, chi2cdf = 1.0
# idx = 24923, chi2cdf = 1.0
# idx = 24924, chi2cdf = 1.0
# idx = 24925, chi2cdf = 1.0
# idx = 24926, chi2cdf = 1.0
# idx = 24927, chi2cdf = 1.0
# idx = 24928, chi2cdf = 1.0
# idx = 24929, chi2cdf = 1.0
# idx = 24930, chi2cdf = 1.0
# idx = 24931, chi2cdf = 1.0
# idx = 24932, chi2cdf = 1.0
# idx = 24933, chi2cdf = 1.0
# idx = 24934, chi2cdf = 1.0
# idx = 24935, chi2cdf = 1.0
# idx = 24936, chi2cdf = 1.0
# idx = 24937, chi2cdf = 1.0
# idx = 24938, chi2cdf = 1.0
# idx = 24939, chi2cdf = 1.0
# idx = 24940, chi2cdf = 1.0
# idx = 24941, chi2cdf = 1.0
# idx = 24942, chi2cdf = 1.0
# idx = 24943, chi2cdf = 1.0
# idx = 24944, chi2cdf = 1.0
# idx = 24945, chi2cdf = 1.0
# idx = 24946, chi2cdf = 1.0
# idx = 24947, chi2cdf = 1.0
# idx = 24948, chi2cdf = 1.0
# idx = 24949, chi2cdf = 1.0
# idx = 24950, chi2cdf = 1.0
# idx = 24951, chi2cdf = 1.0
# idx = 24952, chi2cdf = 1.0
# idx = 24953, chi2cdf = 1.0
# idx = 24958, chi2cdf = 1.0
# idx = 24959, chi2cdf = 1.0
# idx = 24960, chi2cdf = 1.0
# idx = 24961, chi2cdf = 1.0
# idx = 24962, chi2cdf = 1.0
# idx = 24963, chi2cdf = 1.0
# idx = 24964, chi2cdf = 1.0
# idx = 24965, chi2cdf = 1.0
# idx = 24966, chi2cdf = 1.0
# idx = 24967, chi2cdf = 1.0
# idx = 24968, chi2cdf = 1.0
# idx = 24969, chi2cdf = 1.0
# idx = 24970, chi2cdf = 1.0
# idx = 24971, chi2cdf = 1.0
# idx = 24972, chi2cdf = 1.0
# idx = 24973, chi2cdf = 1.0
# idx = 24974, chi2cdf = 1.0
# idx = 24975, chi2cdf = 1.0
# idx = 24976, chi2cdf = 1.0
# idx = 24977, chi2cdf = 1.0
# idx = 24978, chi2cdf = 1.0
# idx = 24979, chi2cdf = 1.0
# idx = 24980, chi2cdf = 1.0
# idx = 24981, chi2cdf = 1.0
# idx = 24982, chi2cdf = 1.0
# idx = 24983, chi2cdf = 1.0
# idx = 24984, chi2cdf = 1.0
# idx = 24985, chi2cdf = 1.0
# idx = 24986, chi2cdf = 1.0
# idx = 24987, chi2cdf = 1.0
# idx = 24988, chi2cdf = 1.0
# idx = 24989, chi2cdf = 1.0
# idx = 24990, chi2cdf = 1.0
# idx = 24991, chi2cdf = 1.0
# idx = 24992, chi2cdf = 1.0
# idx = 24993, chi2cdf = 1.0
# idx = 24994, chi2cdf = 1.0
# idx = 24995, chi2cdf = 1.0
# idx = 24996, chi2cdf = 1.0
# idx = 24997, chi2cdf = 1.0
# idx = 24998, chi2cdf = 1.0
# idx = 24999, chi2cdf = 1.0
# idx = 25000, chi2cdf = 1.0
# idx = 25001, chi2cdf = 1.0
# idx = 25002, chi2cdf = 1.0
# idx = 25003, chi2cdf = 1.0
# idx = 25004, chi2cdf = 1.0
# idx = 25005, chi2cdf = 1.0
# idx = 25006, chi2cdf = 1.0
# idx = 25007, chi2cdf = 1.0
# idx = 25008, chi2cdf = 1.0
# idx = 25009, chi2cdf = 1.0
# idx = 25011, chi2cdf = 1.0
# idx = 25012, chi2cdf = 1.0
# idx = 25013, chi2cdf = 1.0
# idx = 25014, chi2cdf = 1.0
# idx = 25016, chi2cdf = 1.0
# idx = 25017, chi2cdf = 1.0
# idx = 25019, chi2cdf = 1.0
# idx = 25020, chi2cdf = 1.0
# idx = 25022, chi2cdf = 1.0
# idx = 25023, chi2cdf = 1.0
# idx = 25024, chi2cdf = 1.0
# idx = 25025, chi2cdf = 1.0
# idx = 25026, chi2cdf = 1.0
# idx = 25027, chi2cdf = 1.0
# idx = 25028, chi2cdf = 1.0
# idx = 25029, chi2cdf = 1.0
# idx = 25030, chi2cdf = 1.0
# idx = 25031, chi2cdf = 1.0
# idx = 25032, chi2cdf = 1.0
# idx = 25033, chi2cdf = 1.0
# idx = 25034, chi2cdf = 1.0
# idx = 25035, chi2cdf = 1.0
# idx = 25036, chi2cdf = 1.0
# idx = 25037, chi2cdf = 1.0
# idx = 25038, chi2cdf = 1.0
# idx = 25039, chi2cdf = 1.0
# idx = 25040, chi2cdf = 1.0
# idx = 25041, chi2cdf = 1.0
# idx = 25042, chi2cdf = 1.0
# idx = 25043, chi2cdf = 1.0
# idx = 25044, chi2cdf = 1.0
# idx = 25045, chi2cdf = 1.0
# idx = 25046, chi2cdf = 1.0
# idx = 25047, chi2cdf = 1.0
# idx = 25048, chi2cdf = 1.0
# idx = 25049, chi2cdf = 1.0
# idx = 25050, chi2cdf = 1.0
# idx = 25051, chi2cdf = 1.0
# idx = 25052, chi2cdf = 1.0
# idx = 25053, chi2cdf = 1.0
# idx = 25054, chi2cdf = 1.0
# idx = 25055, chi2cdf = 1.0
# idx = 25056, chi2cdf = 1.0
# idx = 25057, chi2cdf = 1.0
# idx = 25058, chi2cdf = 1.0
# idx = 25059, chi2cdf = 1.0
# idx = 25060, chi2cdf = 1.0
# idx = 25061, chi2cdf = 1.0
# idx = 25062, chi2cdf = 1.0
# idx = 25063, chi2cdf = 1.0
# idx = 25064, chi2cdf = 1.0
# idx = 25065, chi2cdf = 1.0
# idx = 25066, chi2cdf = 1.0
# idx = 25067, chi2cdf = 1.0
# idx = 25068, chi2cdf = 1.0
# idx = 25069, chi2cdf = 1.0
# idx = 25070, chi2cdf = 1.0
# idx = 25071, chi2cdf = 1.0
# idx = 25072, chi2cdf = 1.0
# idx = 25073, chi2cdf = 1.0
# idx = 25074, chi2cdf = 1.0
# idx = 25075, chi2cdf = 1.0
# idx = 25076, chi2cdf = 1.0
# idx = 25077, chi2cdf = 1.0
# idx = 25078, chi2cdf = 1.0
# idx = 25079, chi2cdf = 1.0
# idx = 25080, chi2cdf = 1.0
# idx = 25081, chi2cdf = 1.0
# idx = 25082, chi2cdf = 1.0
# idx = 25083, chi2cdf = 1.0
# idx = 25084, chi2cdf = 1.0
# idx = 25086, chi2cdf = 1.0
# idx = 25087, chi2cdf = 1.0
# idx = 25089, chi2cdf = 1.0
# idx = 25090, chi2cdf = 1.0
# idx = 25091, chi2cdf = 1.0
# idx = 25092, chi2cdf = 1.0
# idx = 25094, chi2cdf = 1.0
# idx = 25095, chi2cdf = 1.0
# idx = 25097, chi2cdf = 1.0
# idx = 25098, chi2cdf = 1.0
# idx = 25099, chi2cdf = 1.0
# idx = 25100, chi2cdf = 1.0
# idx = 25101, chi2cdf = 1.0
# idx = 25102, chi2cdf = 1.0
# idx = 25103, chi2cdf = 1.0
# idx = 25104, chi2cdf = 1.0
# idx = 25105, chi2cdf = 1.0
# idx = 25106, chi2cdf = 1.0
# idx = 25107, chi2cdf = 1.0
# idx = 25108, chi2cdf = 1.0
# idx = 25109, chi2cdf = 1.0
# idx = 25110, chi2cdf = 1.0
# idx = 25111, chi2cdf = 1.0
# idx = 25112, chi2cdf = 1.0
# idx = 25113, chi2cdf = 1.0
# idx = 25114, chi2cdf = 1.0
# idx = 25115, chi2cdf = 1.0
# idx = 25116, chi2cdf = 1.0
# idx = 25117, chi2cdf = 1.0
# idx = 25118, chi2cdf = 1.0
# idx = 25119, chi2cdf = 1.0
# idx = 25120, chi2cdf = 1.0
# idx = 25121, chi2cdf = 1.0
# idx = 25122, chi2cdf = 1.0
# idx = 25123, chi2cdf = 1.0
# idx = 25124, chi2cdf = 1.0
# idx = 25125, chi2cdf = 1.0
# idx = 25126, chi2cdf = 1.0
# idx = 25127, chi2cdf = 1.0
# idx = 25128, chi2cdf = 1.0
# idx = 25129, chi2cdf = 1.0
# idx = 25130, chi2cdf = 1.0
# idx = 25131, chi2cdf = 1.0
# idx = 25132, chi2cdf = 1.0
# idx = 25133, chi2cdf = 1.0
# idx = 25134, chi2cdf = 1.0
# idx = 25135, chi2cdf = 1.0
# idx = 25136, chi2cdf = 1.0
# idx = 25137, chi2cdf = 1.0
# idx = 25138, chi2cdf = 1.0
# idx = 25139, chi2cdf = 1.0
# idx = 25140, chi2cdf = 1.0
# idx = 25141, chi2cdf = 1.0
# idx = 25142, chi2cdf = 1.0
# idx = 25143, chi2cdf = 1.0
# idx = 25144, chi2cdf = 1.0
# idx = 25145, chi2cdf = 1.0
# idx = 25146, chi2cdf = 1.0
# idx = 25147, chi2cdf = 1.0
# idx = 25148, chi2cdf = 1.0
# idx = 25149, chi2cdf = 1.0
# idx = 25150, chi2cdf = 1.0
# idx = 25151, chi2cdf = 1.0
# idx = 25152, chi2cdf = 1.0
# idx = 25153, chi2cdf = 1.0
# idx = 25154, chi2cdf = 1.0
# ...
# idx = 26494, chi2cdf = 1.0
# idx = 26495, chi2cdf = 1.0
# idx = 26496, chi2cdf = 1.0
# idx = 26497, chi2cdf = 1.0
# idx = 26498, chi2cdf = 1.0
# idx = 26499, chi2cdf = 1.0
# idx = 26500, chi2cdf = 1.0
# idx = 26501, chi2cdf = 1.0
# idx = 26502, chi2cdf = 1.0
# idx = 26503, chi2cdf = 1.0
# idx = 26504, chi2cdf = 1.0
# idx = 26505, chi2cdf = 1.0
# idx = 26506, chi2cdf = 1.0
# idx = 26507, chi2cdf = 1.0
# idx = 26508, chi2cdf = 1.0
# idx = 26509, chi2cdf = 1.0
# idx = 26510, chi2cdf = 1.0
# idx = 26511, chi2cdf = 1.0
# idx = 26512, chi2cdf = 1.0
# idx = 26513, chi2cdf = 1.0
# idx = 26514, chi2cdf = 1.0
# idx = 26515, chi2cdf = 1.0
# idx = 26516, chi2cdf = 1.0
# idx = 26517, chi2cdf = 1.0
# idx = 26518, chi2cdf = 1.0
# idx = 26519, chi2cdf = 1.0
# idx = 26520, chi2cdf = 1.0
# idx = 26521, chi2cdf = 1.0
# idx = 26522, chi2cdf = 1.0
# idx = 26523, chi2cdf = 1.0
# idx = 26524, chi2cdf = 1.0
# idx = 26525, chi2cdf = 1.0
# idx = 26526, chi2cdf = 1.0
# idx = 26527, chi2cdf = 1.0
# idx = 26528, chi2cdf = 1.0
# idx = 26529, chi2cdf = 1.0
# idx = 26530, chi2cdf = 1.0
# idx = 26531, chi2cdf = 1.0
# idx = 26532, chi2cdf = 1.0
# idx = 26533, chi2cdf = 1.0
# idx = 26534, chi2cdf = 1.0
# idx = 26535, chi2cdf = 1.0
# idx = 26536, chi2cdf = 1.0
# idx = 26537, chi2cdf = 1.0
# idx = 26538, chi2cdf = 1.0
# idx = 26539, chi2cdf = 1.0
# idx = 26540, chi2cdf = 1.0
# idx = 26541, chi2cdf = 1.0
# idx = 26542, chi2cdf = 1.0
# idx = 26544, chi2cdf = 1.0
# idx = 26545, chi2cdf = 1.0
# idx = 26546, chi2cdf = 1.0
# idx = 26547, chi2cdf = 1.0
# idx = 26548, chi2cdf = 1.0
# idx = 26549, chi2cdf = 1.0
# idx = 26550, chi2cdf = 1.0
# idx = 26551, chi2cdf = 1.0
# idx = 26552, chi2cdf = 1.0
# idx = 26553, chi2cdf = 1.0
# idx = 26555, chi2cdf = 1.0
# idx = 26556, chi2cdf = 1.0
# idx = 26557, chi2cdf = 1.0
# idx = 26558, chi2cdf = 1.0
# idx = 26559, chi2cdf = 1.0
# idx = 26560, chi2cdf = 1.0
# idx = 26561, chi2cdf = 1.0
# idx = 26563, chi2cdf = 1.0
# idx = 26564, chi2cdf = 1.0
# idx = 26565, chi2cdf = 1.0
# idx = 26568, chi2cdf = 1.0
# idx = 26569, chi2cdf = 1.0
# idx = 26570, chi2cdf = 1.0
# idx = 26571, chi2cdf = 1.0
# idx = 26572, chi2cdf = 1.0
# idx = 26573, chi2cdf = 1.0
# idx = 26575, chi2cdf = 1.0
# idx = 26576, chi2cdf = 1.0
# idx = 26577, chi2cdf = 1.0
# idx = 26579, chi2cdf = 1.0
# idx = 26580, chi2cdf = 1.0
# idx = 26581, chi2cdf = 1.0
# idx = 26582, chi2cdf = 1.0
# idx = 26583, chi2cdf = 1.0
# idx = 26584, chi2cdf = 1.0
# idx = 26585, chi2cdf = 1.0
# idx = 26589, chi2cdf = 1.0
# idx = 26590, chi2cdf = 1.0
# idx = 26591, chi2cdf = 1.0
# idx = 26592, chi2cdf = 1.0
# idx = 26593, chi2cdf = 1.0
# idx = 26594, chi2cdf = 1.0
# idx = 26595, chi2cdf = 1.0
# idx = 26596, chi2cdf = 1.0
# idx = 26599, chi2cdf = 1.0
# idx = 26601, chi2cdf = 1.0
# idx = 26605, chi2cdf = 1.0
# idx = 26607, chi2cdf = 1.0
# idx = 26611, chi2cdf = 1.0
# idx = 26613, chi2cdf = 1.0
# idx = 26616, chi2cdf = 1.0
# idx = 26619, chi2cdf = 1.0
# idx = 26621, chi2cdf = 1.0
# idx = 26623, chi2cdf = 1.0
# idx = 26626, chi2cdf = 1.0
# idx = 26630, chi2cdf = 1.0
# idx = 26631, chi2cdf = 1.0
# idx = 26633, chi2cdf = 1.0
# idx = 26634, chi2cdf = 1.0
# idx = 26635, chi2cdf = 1.0
# idx = 26637, chi2cdf = 1.0
# idx = 26639, chi2cdf = 1.0
# idx = 26640, chi2cdf = 1.0
# idx = 26642, chi2cdf = 1.0
# idx = 26645, chi2cdf = 1.0
# idx = 26649, chi2cdf = 1.0
# idx = 26650, chi2cdf = 1.0
# idx = 26652, chi2cdf = 1.0
# idx = 26653, chi2cdf = 1.0
# idx = 26655, chi2cdf = 1.0
# idx = 26659, chi2cdf = 1.0
# idx = 26660, chi2cdf = 1.0
# idx = 26661, chi2cdf = 1.0
# idx = 26662, chi2cdf = 1.0
# idx = 26663, chi2cdf = 1.0
# idx = 26668, chi2cdf = 1.0
# idx = 26670, chi2cdf = 1.0
# idx = 26672, chi2cdf = 1.0
# idx = 26674, chi2cdf = 1.0
# idx = 26675, chi2cdf = 1.0
# idx = 26676, chi2cdf = 1.0
# idx = 26677, chi2cdf = 1.0
# idx = 26678, chi2cdf = 1.0
# idx = 26679, chi2cdf = 1.0
# idx = 26681, chi2cdf = 1.0
# idx = 26683, chi2cdf = 1.0
# idx = 26684, chi2cdf = 1.0
# idx = 26686, chi2cdf = 1.0
# idx = 26688, chi2cdf = 1.0
# idx = 26689, chi2cdf = 1.0
# idx = 26691, chi2cdf = 1.0
# idx = 26694, chi2cdf = 1.0
# idx = 26695, chi2cdf = 1.0
# idx = 26696, chi2cdf = 1.0
# idx = 26698, chi2cdf = 1.0
# idx = 26700, chi2cdf = 1.0
# idx = 26702, chi2cdf = 1.0
# idx = 26703, chi2cdf = 1.0
# idx = 26705, chi2cdf = 1.0
# idx = 26708, chi2cdf = 1.0
# idx = 26710, chi2cdf = 1.0
# idx = 26713, chi2cdf = 1.0
# idx = 26716, chi2cdf = 1.0
# idx = 26718, chi2cdf = 1.0
# idx = 26720, chi2cdf = 1.0
# idx = 26722, chi2cdf = 1.0
# idx = 26725, chi2cdf = 1.0
# idx = 26726, chi2cdf = 1.0
# idx = 26728, chi2cdf = 1.0
# idx = 26729, chi2cdf = 1.0
# idx = 26731, chi2cdf = 1.0
# idx = 26733, chi2cdf = 1.0
# idx = 26735, chi2cdf = 1.0
# idx = 26736, chi2cdf = 1.0
# idx = 26740, chi2cdf = 1.0
# idx = 26741, chi2cdf = 1.0
# idx = 26745, chi2cdf = 1.0
# idx = 26747, chi2cdf = 1.0
# idx = 26748, chi2cdf = 1.0
# idx = 26749, chi2cdf = 1.0
# idx = 26750, chi2cdf = 1.0
# idx = 26751, chi2cdf = 1.0
# idx = 26752, chi2cdf = 1.0
# idx = 26753, chi2cdf = 1.0
# idx = 26754, chi2cdf = 1.0
# idx = 26755, chi2cdf = 1.0
# idx = 26758, chi2cdf = 1.0
# idx = 26759, chi2cdf = 1.0
# idx = 26760, chi2cdf = 1.0
# idx = 26761, chi2cdf = 1.0
# idx = 26762, chi2cdf = 1.0
# idx = 26765, chi2cdf = 1.0
# idx = 26767, chi2cdf = 1.0
# idx = 26768, chi2cdf = 1.0
# idx = 26771, chi2cdf = 1.0
# idx = 26772, chi2cdf = 1.0
# idx = 26773, chi2cdf = 1.0
# idx = 26776, chi2cdf = 1.0
# idx = 26777, chi2cdf = 1.0
# idx = 26778, chi2cdf = 1.0
# idx = 26781, chi2cdf = 1.0
# idx = 26783, chi2cdf = 1.0
# idx = 26784, chi2cdf = 1.0
# idx = 26790, chi2cdf = 1.0
# idx = 26792, chi2cdf = 1.0
# idx = 26793, chi2cdf = 1.0
# idx = 26794, chi2cdf = 1.0
# idx = 26795, chi2cdf = 1.0
# idx = 26797, chi2cdf = 1.0
# idx = 26801, chi2cdf = 1.0
# idx = 26803, chi2cdf = 1.0
# idx = 26804, chi2cdf = 1.0
# idx = 26807, chi2cdf = 1.0
# idx = 26808, chi2cdf = 1.0
# idx = 26809, chi2cdf = 1.0
# idx = 26810, chi2cdf = 1.0
# idx = 26811, chi2cdf = 1.0
# idx = 26814, chi2cdf = 1.0
# idx = 26817, chi2cdf = 1.0
# idx = 26818, chi2cdf = 1.0
# idx = 26819, chi2cdf = 1.0
# idx = 26820, chi2cdf = 1.0
# idx = 26823, chi2cdf = 1.0
# idx = 26826, chi2cdf = 1.0
# idx = 26827, chi2cdf = 1.0
# idx = 26828, chi2cdf = 1.0
# idx = 26832, chi2cdf = 1.0
# idx = 26833, chi2cdf = 1.0
# idx = 26834, chi2cdf = 1.0
# idx = 26835, chi2cdf = 1.0
# idx = 26838, chi2cdf = 1.0
# idx = 26839, chi2cdf = 1.0
# idx = 26840, chi2cdf = 1.0
# idx = 26841, chi2cdf = 1.0
# idx = 26845, chi2cdf = 1.0
# idx = 26846, chi2cdf = 1.0
# idx = 26848, chi2cdf = 1.0
# idx = 26849, chi2cdf = 1.0
# idx = 26851, chi2cdf = 1.0
# idx = 26852, chi2cdf = 1.0
# idx = 26853, chi2cdf = 1.0
# idx = 26855, chi2cdf = 1.0
# idx = 26858, chi2cdf = 1.0
# idx = 26859, chi2cdf = 1.0
# idx = 26862, chi2cdf = 1.0
# idx = 26863, chi2cdf = 1.0
# idx = 26864, chi2cdf = 1.0
# idx = 26866, chi2cdf = 1.0
# idx = 26867, chi2cdf = 1.0
# idx = 26868, chi2cdf = 1.0
# idx = 26870, chi2cdf = 1.0
# idx = 26871, chi2cdf = 1.0
# idx = 26874, chi2cdf = 1.0
# idx = 26876, chi2cdf = 1.0
# idx = 26877, chi2cdf = 1.0
# idx = 26879, chi2cdf = 1.0
# idx = 26883, chi2cdf = 1.0
# idx = 26884, chi2cdf = 1.0
# idx = 26885, chi2cdf = 1.0
# idx = 26886, chi2cdf = 1.0
# idx = 26888, chi2cdf = 1.0
# idx = 26890, chi2cdf = 1.0
# idx = 26893, chi2cdf = 1.0
# idx = 26895, chi2cdf = 1.0
# idx = 26896, chi2cdf = 1.0
# idx = 26897, chi2cdf = 1.0
# idx = 26898, chi2cdf = 1.0
# idx = 26899, chi2cdf = 1.0
# idx = 26901, chi2cdf = 1.0
# idx = 26903, chi2cdf = 1.0
# idx = 26904, chi2cdf = 1.0
# idx = 26905, chi2cdf = 1.0
# idx = 26907, chi2cdf = 1.0
# idx = 26910, chi2cdf = 1.0
# idx = 26913, chi2cdf = 1.0
# idx = 26916, chi2cdf = 1.0
# idx = 26917, chi2cdf = 1.0
# idx = 26918, chi2cdf = 1.0
# idx = 26919, chi2cdf = 1.0
# idx = 26920, chi2cdf = 1.0
# idx = 26923, chi2cdf = 1.0
# idx = 26924, chi2cdf = 1.0
# idx = 26928, chi2cdf = 1.0
# idx = 26929, chi2cdf = 1.0
# idx = 26930, chi2cdf = 1.0
# idx = 26933, chi2cdf = 1.0
# idx = 26934, chi2cdf = 1.0
# idx = 26935, chi2cdf = 1.0
# idx = 26936, chi2cdf = 1.0
# idx = 26940, chi2cdf = 1.0
# idx = 26942, chi2cdf = 1.0
# idx = 26943, chi2cdf = 1.0
# idx = 26944, chi2cdf = 1.0
# idx = 26946, chi2cdf = 1.0
# idx = 26947, chi2cdf = 1.0
# idx = 26948, chi2cdf = 1.0
# idx = 26949, chi2cdf = 1.0
# idx = 26950, chi2cdf = 1.0
# idx = 26954, chi2cdf = 1.0
# idx = 26957, chi2cdf = 1.0
# idx = 26958, chi2cdf = 1.0
# idx = 26960, chi2cdf = 1.0
# idx = 26961, chi2cdf = 1.0
# idx = 26962, chi2cdf = 1.0
# idx = 26965, chi2cdf = 1.0
# idx = 26966, chi2cdf = 1.0
# idx = 26969, chi2cdf = 1.0
# idx = 26970, chi2cdf = 1.0
# idx = 26972, chi2cdf = 1.0
# idx = 26973, chi2cdf = 1.0
# idx = 26976, chi2cdf = 1.0
# idx = 26978, chi2cdf = 1.0
# idx = 26979, chi2cdf = 1.0
# idx = 26980, chi2cdf = 1.0
# idx = 26981, chi2cdf = 1.0
# idx = 26983, chi2cdf = 1.0
# idx = 26984, chi2cdf = 1.0
# idx = 26985, chi2cdf = 1.0
# idx = 26987, chi2cdf = 1.0
# idx = 26991, chi2cdf = 1.0
# idx = 26993, chi2cdf = 1.0
# idx = 26994, chi2cdf = 1.0
# idx = 26996, chi2cdf = 1.0
# idx = 26998, chi2cdf = 1.0
# idx = 26999, chi2cdf = 1.0
# idx = 27000, chi2cdf = 1.0
# idx = 27001, chi2cdf = 1.0
# idx = 27002, chi2cdf = 1.0
# idx = 27003, chi2cdf = 1.0
# idx = 27004, chi2cdf = 1.0
# idx = 27009, chi2cdf = 1.0
# idx = 27014, chi2cdf = 1.0
# idx = 27015, chi2cdf = 1.0
# idx = 27017, chi2cdf = 1.0
# idx = 27018, chi2cdf = 1.0
# idx = 27019, chi2cdf = 1.0
# idx = 27020, chi2cdf = 1.0
# idx = 27022, chi2cdf = 1.0
# idx = 27024, chi2cdf = 1.0
# idx = 27025, chi2cdf = 1.0
# idx = 27026, chi2cdf = 1.0
# idx = 27027, chi2cdf = 1.0
# idx = 27028, chi2cdf = 1.0
# idx = 27029, chi2cdf = 1.0
# idx = 27031, chi2cdf = 1.0
# idx = 27033, chi2cdf = 1.0
# idx = 36454, chi2cdf = 1.0
# idx = 36464, chi2cdf = 1.0
# idx = 36485, chi2cdf = 1.0
# idx = 36494, chi2cdf = 1.0
# idx = 36512, chi2cdf = 1.0
# idx = 36522, chi2cdf = 1.0
# idx = 36543, chi2cdf = 1.0
# idx = 36557, chi2cdf = 1.0
# idx = 36561, chi2cdf = 1.0
# idx = 36574, chi2cdf = 1.0
# idx = 36583, chi2cdf = 1.0
# idx = 36593, chi2cdf = 1.0
# idx = 36606, chi2cdf = 1.0
# idx = 36618, chi2cdf = 1.0
# idx = 36630, chi2cdf = 1.0
# idx = 36637, chi2cdf = 1.0
# idx = 36651, chi2cdf = 1.0
# idx = 36654, chi2cdf = 1.0
# idx = 36673, chi2cdf = 1.0
# idx = 36676, chi2cdf = 1.0
# idx = 36687, chi2cdf = 1.0
# idx = 36702, chi2cdf = 1.0
# idx = 36707, chi2cdf = 1.0
# idx = 36733, chi2cdf = 1.0
# idx = 36744, chi2cdf = 1.0
# idx = 36748, chi2cdf = 1.0
# idx = 36756, chi2cdf = 1.0
# idx = 36765, chi2cdf = 1.0
# idx = 36774, chi2cdf = 1.0
# idx = 36777, chi2cdf = 1.0
# idx = 36783, chi2cdf = 1.0
# idx = 36843, chi2cdf = 1.0
# idx = 36854, chi2cdf = 1.0
# idx = 36864, chi2cdf = 1.0
# idx = 36873, chi2cdf = 1.0
# idx = 36884, chi2cdf = 1.0
# idx = 36907, chi2cdf = 1.0
# idx = 36908, chi2cdf = 1.0
# idx = 36909, chi2cdf = 1.0
# idx = 36915, chi2cdf = 1.0
# idx = 36924, chi2cdf = 1.0
# idx = 36940, chi2cdf = 1.0
# idx = 36946, chi2cdf = 1.0
# idx = 36964, chi2cdf = 1.0
# idx = 36972, chi2cdf = 1.0
# idx = 36983, chi2cdf = 1.0
# idx = 36986, chi2cdf = 1.0
# idx = 36989, chi2cdf = 1.0
# idx = 36993, chi2cdf = 1.0
# idx = 36995, chi2cdf = 1.0
# idx = 37006, chi2cdf = 1.0
# idx = 37013, chi2cdf = 1.0
# idx = 37019, chi2cdf = 1.0
# idx = 37042, chi2cdf = 1.0
# idx = 37064, chi2cdf = 1.0
# idx = 37074, chi2cdf = 1.0
# idx = 37084, chi2cdf = 1.0
# idx = 37095, chi2cdf = 1.0
# idx = 37104, chi2cdf = 1.0
# idx = 37113, chi2cdf = 1.0
# idx = 37120, chi2cdf = 1.0
# idx = 37121, chi2cdf = 1.0
# idx = 37128, chi2cdf = 1.0
# idx = 37138, chi2cdf = 1.0
# idx = 37150, chi2cdf = 1.0
# idx = 37160, chi2cdf = 1.0
# idx = 37168, chi2cdf = 1.0
# idx = 37180, chi2cdf = 1.0
# idx = 37188, chi2cdf = 1.0
# idx = 37200, chi2cdf = 1.0
# idx = 37211, chi2cdf = 1.0
# idx = 37219, chi2cdf = 1.0
# idx = 37238, chi2cdf = 1.0
# idx = 37249, chi2cdf = 1.0
# idx = 37258, chi2cdf = 1.0
# idx = 37299, chi2cdf = 1.0
# idx = 37308, chi2cdf = 1.0
# idx = 37312, chi2cdf = 1.0
# idx = 37314, chi2cdf = 1.0
# idx = 37328, chi2cdf = 1.0
# idx = 37339, chi2cdf = 1.0
# idx = 37342, chi2cdf = 1.0
# idx = 37353, chi2cdf = 1.0
# idx = 37362, chi2cdf = 1.0
# idx = 37370, chi2cdf = 1.0
# idx = 37378, chi2cdf = 1.0
# idx = 37379, chi2cdf = 1.0
# idx = 37388, chi2cdf = 1.0
# idx = 37390, chi2cdf = 1.0
# idx = 37402, chi2cdf = 1.0
# idx = 37411, chi2cdf = 1.0
# idx = 37428, chi2cdf = 1.0
# idx = 37434, chi2cdf = 1.0
# idx = 37462, chi2cdf = 1.0
# idx = 37471, chi2cdf = 1.0
# idx = 37486, chi2cdf = 1.0
# idx = 37487, chi2cdf = 1.0
# idx = 37488, chi2cdf = 1.0
# idx = 37489, chi2cdf = 1.0
# idx = 37490, chi2cdf = 1.0
# idx = 37491, chi2cdf = 1.0
# idx = 37503, chi2cdf = 1.0
# idx = 37515, chi2cdf = 1.0
# idx = 37529, chi2cdf = 1.0
# idx = 37531, chi2cdf = 1.0
# idx = 37538, chi2cdf = 1.0
# idx = 37543, chi2cdf = 1.0
# idx = 37556, chi2cdf = 1.0
# idx = 37564, chi2cdf = 1.0
# idx = 37572, chi2cdf = 1.0
# idx = 37587, chi2cdf = 1.0
# idx = 37589, chi2cdf = 1.0
# idx = 37590, chi2cdf = 1.0
# idx = 37591, chi2cdf = 1.0
# idx = 37592, chi2cdf = 1.0
# idx = 37597, chi2cdf = 1.0
# idx = 37609, chi2cdf = 1.0
# idx = 37625, chi2cdf = 1.0
# idx = 37646, chi2cdf = 1.0
# idx = 37655, chi2cdf = 1.0
# idx = 37663, chi2cdf = 1.0
# idx = 37668, chi2cdf = 1.0
# idx = 37696, chi2cdf = 1.0
# idx = 37705, chi2cdf = 1.0
# idx = 37726, chi2cdf = 1.0
# idx = 37731, chi2cdf = 1.0
# idx = 37742, chi2cdf = 1.0
# idx = 37749, chi2cdf = 1.0
# idx = 37761, chi2cdf = 1.0
# idx = 37767, chi2cdf = 1.0
# idx = 37774, chi2cdf = 1.0
# idx = 37780, chi2cdf = 1.0
# idx = 37790, chi2cdf = 1.0
# idx = 37793, chi2cdf = 1.0
# idx = 37804, chi2cdf = 1.0
# idx = 37819, chi2cdf = 1.0
# idx = 37832, chi2cdf = 1.0
# idx = 37844, chi2cdf = 1.0
# idx = 37855, chi2cdf = 1.0
# idx = 37860, chi2cdf = 1.0
# idx = 37867, chi2cdf = 1.0
# idx = 37873, chi2cdf = 1.0
# idx = 37880, chi2cdf = 1.0
# idx = 37883, chi2cdf = 1.0
# idx = 37897, chi2cdf = 1.0
# idx = 37905, chi2cdf = 1.0
# idx = 37912, chi2cdf = 1.0
# idx = 37926, chi2cdf = 1.0
# idx = 37935, chi2cdf = 1.0
# idx = 37946, chi2cdf = 1.0
# idx = 37952, chi2cdf = 1.0
# idx = 37973, chi2cdf = 1.0
#                    hash  offset  bitsPerSample  srcLittleEndian  \
# 8511   01701bf8635b2095       0             16            False
# 8564   708a5474d5bf9cf8       0             16             True
# 8572   1f839344d1585d48       0             16             True
# 17821  0d45f80a53c46f18       0             16             True
# 23205  058cad01a53ca801       0              8            False
# ...                 ...     ...            ...              ...
# 37926  699568eaf77c0227       0              0             True
# 37935  1a40f73191b1b194       0              0             True
# 37946  0c65aef169d703b1       0              0             True
# 37952  78dd53d98f1bcf8a       0              0             True
# 37973  44eb9a12378d04f5       0              0             True
#
#        dstLittleEndian  dim        m  stride            N      Mtotal  \
# 8511              True    8        2       2        25600         256
# 8564             False    8        2       2        25600         256
# 8572             False    9        2       2        25600         512
# 17821             True    3        4       4      6400000          64
# 23205            False    1        2       0           40           2
# ...                ...  ...      ...     ...          ...         ...
# 37926             True    6       30       0  72900000000   729000000
# 37935             True    3      200       0  80000000000     8000000
# 37946             True    4      200       0  80000000000  1600000000
# 37952             True    4       30       0  81000000000      810000
# 37973             True    1  8388608       0  83886080000     8388608
#
#        curtask  Ntasks          sum                  sum2   chi2cdf  \
# 8511         0       1        25600               2598596  1.000000
# 8564         0       1        25600               2598596  1.000000
# 8572         0       1        25600               1314528  1.000000
# 17821        0       1      6400000          640013193954  0.999999
# 23205        0       1           40                  1600  1.000000
# ...        ...     ...          ...                   ...       ...
# 37926        0       1  72900000000   1747706771649134592  1.000000
# 37935        0       1  80000000000  17426550496495140864  1.000000
# 37946        0       1  80000000000  17426550496495140864  1.000000
# 37952        0       1  81000000000  12405853833109176320  1.000000
# 37973        0       1  83886080000   8664925683060834304  1.000000
#
#        parameters_ok
# 8511            True
# 8564            True
# 8572            True
# 17821           True
# 23205           True
# ...              ...
# 37926           True
# 37935           True
# 37946           True
# 37952           True
# 37973           True
#
# [3504 rows x 16 columns]
