# %%
import pandas as pd

# %%
with open("../results.csv", "r") as f:
    df = pd.read_csv(f, sep=" ")

# %%
df
# Out:
#      rng  offset  dim    m        N  Mtot  curtask  Ntasks      sum  \
# 0      1       0    1   20     2000    20        0       1     2000
# 1      1       0    1  100     1000   100        0       1     1000
# 2      1       0    1  100     2000   100        0       1     2000
# 3      1       0    1   10    10000    10        0       1    10000
# 4      1       0    1  100     5000   100        0       1     5000
# ..   ...     ...  ...  ...      ...   ...      ...     ...      ...
# 394    1       0    1   20   200000    20        0       1   200000
# 395    1       0    1   20   200000    20        0       1   200000
# 396    1       0    1  100  1000000   100        0       1  1000000
# 397    1       0    1   10  1000000    10        0       1  1000000
# 398    1       0    1   20  2000000    20        0       1  2000000
#
#              sum2   chi2cdf
# 0          201518  0.288910
# 1           10882  0.226775
# 2           41624  0.096500
# 3        10010618  0.697196
# ...
