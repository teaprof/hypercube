# %%
import pandas as pd

# %%
with open("../results.csv", "r") as f:
    df = pd.read_csv(f, sep=" ")

# %%
df
# Out:
#      rng  offset  dim    m          N     Mtot  curtask  Ntasks        sum  \
# 0      1       0    1   20       2000       20        0       1       2000
# 1      1       0    1  100       1000      100        0       1       1000
# 2      1       0    1  100       2000      100        0       1       2000
# 3      1       0    1   10      10000       10        0       1      10000
# 4      1       0    1  100       5000      100        0       1       5000
# ..   ...     ...  ...  ...        ...      ...      ...     ...        ...
# 340    1       0    4   20    1600000   160000        0       1    1600000
# 341    1       0    4   20    3200000   160000        0       1    3200000
# 342    1       0    4   20    8000000   160000        0       1    8000000
# 343    1       0    3  100  100000000  1000000        0       1  100000000
# 344    1       0    4   20   16000000   160000        0       1   16000000
#
#             sum2   chi2cdf
# 0         201518  0.288910
# ...
